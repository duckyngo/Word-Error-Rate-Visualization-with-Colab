# %% [markdown]
# <a href="https://colab.research.google.com/github/duckyngo/Word-Error-Rate-Visualization-with-Colab/blob/main/Manifest_STT_Calculate_WER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from IPython.display import HTML, display
try:
  import jiwer
except:
  # !pip install jiwer
  import jiwer


def wer(ref, hyp ,debug=False):
    r = ref.split()
    h = hyp.split()
    #costs will holds the costs, like in the Levenshtein distance algorithm
    costs = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]
    # backtrace will hold the operations we've done.
    # so we could later backtrace, like the WER algorithm requires us to.
    backtrace = [[0 for inner in range(len(h)+1)] for outer in range(len(r)+1)]

    OP_OK = 0
    OP_SUB = 1
    OP_INS = 2
    OP_DEL = 3

    DEL_PENALTY=1 # Tact
    INS_PENALTY=1 # Tact
    SUB_PENALTY=1 # Tact
    # First column represents the case where we achieve zero
    # hypothesis words by deleting all reference words.
    for i in range(1, len(r)+1):
        costs[i][0] = DEL_PENALTY*i
        backtrace[i][0] = OP_DEL

    # First row represents the case where we achieve the hypothesis
    # by inserting all hypothesis words into a zero-length reference.
    for j in range(1, len(h) + 1):
        costs[0][j] = INS_PENALTY * j
        backtrace[0][j] = OP_INS

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                costs[i][j] = costs[i-1][j-1]
                backtrace[i][j] = OP_OK
            else:
                substitutionCost = costs[i-1][j-1] + SUB_PENALTY # penalty is always 1
                insertionCost    = costs[i][j-1] + INS_PENALTY   # penalty is always 1
                deletionCost     = costs[i-1][j] + DEL_PENALTY   # penalty is always 1

                costs[i][j] = min(substitutionCost, insertionCost, deletionCost)
                if costs[i][j] == substitutionCost:
                    backtrace[i][j] = OP_SUB
                elif costs[i][j] == insertionCost:
                    backtrace[i][j] = OP_INS
                else:
                    backtrace[i][j] = OP_DEL

    # back trace though the best route:
    i = len(r)
    j = len(h)
    numSub = 0
    numDel = 0
    numIns = 0
    numCor = 0
    if debug:
        lines = []
        compares = []
    while i > 0 or j > 0:
        if backtrace[i][j] == OP_OK:
            numCor += 1
            i-=1
            j-=1
            if debug:
                lines.append("OK\t" + r[i]+"\t"+h[j])
                compares.append(colored(0, 0, 0, h[j]))
        elif backtrace[i][j] == OP_SUB:
            numSub +=1
            i-=1
            j-=1
            if debug:
                lines.append("SUB\t" + r[i]+"\t"+h[j])
                compares.append(colored(0, 255, 0, h[j]) +  colored(0, 0, 0, f'({r[i]})'))
        elif backtrace[i][j] == OP_INS:
            numIns += 1
            j-=1
            if debug:
                lines.append("INS\t" + "****" + "\t" + h[j])
                compares.append(colored(0, 0, 255, h[j]))
        elif backtrace[i][j] == OP_DEL:
            numDel += 1
            i-=1
            if debug:
                lines.append("DEL\t" + r[i]+"\t"+"****")
                compares.append(colored(255, 0, 0, r[i]))
    if debug:
        # print("OP\tREF\tHYP")
        # lines = reversed(lines)
        # for line in lines:
        #     print(line)

        compares = reversed(compares)
        for line in compares:
          print(line, end=" ")
        # print("Ncor " + str(numCor))
        # print("Nsub " + str(numSub))
        # print("Ndel " + str(numDel))
        # print("Nins " + str(numIns))
    wer_result = round( (numSub + numDel + numIns) / (float) (len(r)), 3)
    return {'WER':wer_result, 'Cor':numCor, 'Sub':numSub, 'Ins':numIns, 'Del':numDel}, compares


def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))

# Turn on line wrapping on Colab Ref: https://github.com/jupyter/notebook/issues/6274
get_ipython().events.register('pre_run_cell', set_css)


def colored(r, g, b, text):
    return "\033[38;2;{};{};{}m{} \033[38;2;255;255;255m".format(r, g, b, text)

def strike(text, color=None):
    if color:
      return colored(0, 255, 0, ''.join([u'\u0336{}'.format(c) for c in text]))
      
    else:
      return  colored(0, 0, 0, ''.join([u'\u0332{}'.format(c) for c in text]))

#@title Calculate and visualize WER or CER { run: "auto" }

rm_punctuation = True #@param {type:"boolean"}
input_ref='\uB2EC\uBCF4\uB2E4 \uC774 \uC810 \uCE60 \uD37C\uC13C\uD2B8 \uD3EC\uC778\uD2B8 \uB0AE\uC544 \uC84C\uC2B5\uB2C8\uB2E4 \uD314\uC2ED \uD37C\uC13C\uD2B8\uB97C \uB118\uC5B4 \uD3EC\uD654 \uC0C1\uD0DC\uC600\uB358 \uC218\uB3C4\uAD8C \uC911\uC9C4 \uBCD1\uC0C1 \uAC00\uB3D9\uB960\uB3C4 \uC721\uC2ED\uC774 \uC810 \uC0BC \uD37C\uC13C\uD2B8\uB85C \uB5A8\uC5B4\uC84C\uC2B5\uB2C8\uB2E4 \uC9C0\uB09C\uB2EC \uC0BC\uC2ED\uC77C \uCE60\uC2ED \uD37C\uC13C\uD2B8 \uC544\uB798\uB85C \uB5A8\uC5B4\uC9C4 \uB4A4 \uB098\uD758 \uC5F0\uC18D \uD558\uB77D \uC149\uB2C8\uB2E4 \uC9C0\uB09C\uB2EC \uC774\uC2ED \uAD6C\uC77C \uD558\uB8E8\uC5D0\uB9CC \uC624\uBC31 \uC5EC\uB4E0 \uBA85\uC0C1\uC744 \uD655\uCDA9\uD558\uB294 \uB4F1 \uBCD1\uC0C1 \uBD80\uC871 \uC0C1\uD669\uC774 \uB098\uC544\uC9C0\uBA74\uC11C \uC804\uAD6D\uC5D0\uC11C \uD558\uB8E8 \uB118\uAC8C \uC785\uC6D0\uC744 \uAE30\uB2E4\uB9AC\uB294 \uC0AC\uB78C\uC740 \uB2F7\uC0C8\uC9F8 \uD55C \uBA85\uB3C4 \uC5C6\uC5C8\uC2B5\uB2C8\uB2E4 \uBC29\uC5ED \uB2F9\uAD6D\uC740 \uC774\uB2EC \uB9D0\uAE4C\uC9C0 \uC911\uC99D \uD658\uC790 \uBCD1\uC0C1 \uCC9C \uC624\uBC31 \uC77C\uD754 \uC5EC\uB35F\uAC1C\uB97C \uBE44\uB86F\uD574 \uC721\uCC9C \uAD6C\uBC31 \uB9C8\uD754 \uB124\uAC1C\uC758 \uC785\uC6D0 \uBCD1\uC0C1\uC744 \uD655\uCDA9\uD574 \uD558\uB8E8 \uD655\uC9C4 \uB9CC \uBA85\uC5D0\uB3C4 \uB300\uC751\uD558\uACA0\uB2E4\uB294 \uBAA9\uD45C\uC785\uB2C8\uB2E4' #@param {type:"string"}
input_hyp='\uB2EC\uBCF4\uB2E4 \uC774 \uC810 \uCE60 \uD37C\uC13C\uD2B8 \uD3EC\uC778\uD2B8 \uB0AE\uC544\uC84C\uC2B5\uB2C8\uB2E4 \uD314\uC2ED \uD37C\uC13C\uD2B8\uB97C \uB118\uC5B4 \uD3EC\uD55C \uC0C1\uD0DC\uC600\uB358 \uC218\uB3C4\uAD8C \uC911\uC99D\uBCD1\uC0C1 \uAC00\uB3C5\uB960\uB3C4 \uC721\uC2ED \uC774 \uC810 \uC0BC \uD37C\uC13C\uD2B8\uB85C \uB5A8\uC5B4\uC84C\uC2B5\uB2C8\uB2E4 \uC9C0\uB09C \uB2EC \uC0BC\uC2ED \uC77C \uCE60\uC2ED \uD37C\uC13C\uD2B8 \uC544\uB798\uB85C \uB5A8\uC5B4\uC9C4 \uB4A4 \uB098\uD750\uC5F0 \uC18D \uD558\uB77D\uD230\uB2C8\uB2E4 \uC9C0\uB09C \uB2EC \uC774\uC2ED \uAD6C \uC77C \uD558\uB8E8\uC5D0\uB9CC \uC624\uBC31 \uC5EC\uB4E0 \uBCD1\uC0C1\uC744 \uD655\uCDA9\uD558\uB294 \uB4F1 \uBCD1\uC0C1 \uBD80\uC871 \uC0C1\uD669\uC774 \uB098\uC544\uC9C0\uBA74\uC11C \uC804\uAD6D\uC5D0\uC11C \uD558\uB8E8 \uB118\uAC8C \uC774 \uBC88\uC744 \uAE30\uB2E4\uB9AC\uB294 \uC0AC\uB78C\uC740 \uB2E4 \uC14B\uC9F8 \uD55C \uBA85\uB3C4 \uC5C6\uC5C8\uC2B5\uB2C8\uB2E4 \uBC29\uC5ED \uB2E8\uAD6D\uC740 \uC774 \uB2EC \uB9D0\uAE4C\uC9C0 \uC911\uC99D \uD658\uC790 \uBCD1\uC0C1 \uCC9C \uC624\uBC31 \uC77C\uD754 \uC5EC\uB35F \uAC1C\uB97C \uBE44\uC211\uD574 \uC721\uCC9C \uAD6C\uBC31 \uB9C8\uD754 \uB124 \uAC1C\uC5D0 \uC774\uBC88 \uBCD1\uC0C1\uC744 \uD655\uC911\uD574 \uD558\uB8E8 \uD655\uC9C4 \uB9CC\uBA85\uD574\uB3C4 \uB300\uC751\uD558\uACA0\uB2E4\uB294 \uBAA9\uD45C\uB2C8\uB2E4' #@param {type:"string"}
input_json = "" #@param {type:"string"}

if input_json and input_json != "":
  json_data = json.loads(input_json)
  input_ref = json_data['text']
  input_hyp = json_data['pred_text']


if rm_punctuation == True:
    ref = jiwer.RemovePunctuation()(input_ref)
    hyp = jiwer.RemovePunctuation()(input_hyp)
else:
    ref = input_ref
    hyp = input_hyp

print(f"REF: {ref}\n")
print(f"HYP: {hyp}")
print('-'* 30)

output, compares = wer(ref, hyp ,debug=True)

print()
print(colored(0, 0, 0,   f"N CORRECT   : {output['Cor']}"))
print(colored(255, 0, 0, f"N DELETE    : {output['Del']}"))
print(colored(0, 255, 0, f"N SUBSTITUTE: {output['Sub']}"))
print(colored(0, 0, 255, f"N INSERT    : {output['Ins']}"))
print(colored(0, 0, 0, f"WER: {output['WER']}"))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jiwer
#   Downloading jiwer-2.3.0-py3-none-any.whl (15 kB)
# Collecting python-Levenshtein==0.12.2
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 2.9 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein==0.12.2->jiwer) (57.4.0)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149859 sha256=299e682680ddb5a13711436a0333496e8e9643e94a570a5794b69c4525742098
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein, jiwer
# Successfully installed jiwer-2.3.0 python-Levenshtein-0.12.2
# REF: 달보다 이 점 칠 퍼센트 포인트 낮아 졌습니다 팔십 퍼센트를 넘어 포화 상태였던 수도권 중진 병상 가동률도 육십이 점 삼 퍼센트로 떨어졌습니다 지난달 삼십일 칠십 퍼센트 아래로 떨어진 뒤 나흘 연속 하락 셉니다 지난달 이십 구일 하루에만 오백 여든 명상을 확충하는 등 병상 부족 상황이 나아지면서 전국에서 하루 넘게 입원을 기다리는 사람은 닷새째 한 명도 없었습니다 방역 당국은 이달 말까지 중증 환자 병상 천 오백 일흔 여덟개를 비롯해 육천 구백 마흔 네개의 입원 병상을 확충해 하루 확진 만 명에도 대응하겠다는 목표입니다
#
# HYP: 달보다 이 점 칠 퍼센트 포인트 낮아졌습니다 팔십 퍼센트를 넘어 포한 상태였던 수도권 중증병상 가독률도 육십 이 점 삼 퍼센트로 떨어졌습니다 지난 달 삼십 일 칠십 퍼센트 아래로 떨어진 뒤 나흐연 속 하락툰니다 지난 달 이십 구 일 하루에만 오백 여든 병상을 확충하는 등 병상 부족 상황이 나아지면서 전국에서 하루 넘게 이 번을 기다리는 사람은 다 셋째 한 명도 없었습니다 방역 단국은 이 달 말까지 중증 환자 병상 천 오백 일흔 여덟 개를 비숑해 육천 구백 마흔 네 개에 이번 병상을 확중해 하루 확진 만명해도 대응하겠다는 목표니다
# ------------------------------
# 달보다  이  점  칠  퍼센트  포인트  낮아  낮아졌습니다 (졌습니다)  팔십  퍼센트를  넘어  포한 (포화)  상태였던  수도권  중증병상 (중진)  가독률도 (병상)  육십 (가동률도)  이 (육십이)  점  삼  퍼센트로  떨어졌습니다  지난  달  삼십 (지난달)  일 (삼십일)  칠십  퍼센트  아래로  떨어진  뒤  나흐연 (나흘)  속 (연속)  하락툰니다 (하락)  지난 (셉니다)  달 (지난달)  이십  구  일 (구일)  하루에만  오백  여든  병상을 (명상을)  확충하는  등  병상  부족  상황이  나아지면서  전국에서  하루  넘게  이  번을 (입원을)  기다리는  사람은  다  셋째 (닷새째)  한  명도  없었습니다  방역  단국은  이 (당국은)  달 (이달)  말까지  중증  환자  병상  천  오백  일흔  여덟  개를 (여덟개를)  비숑해 (비롯해)  육천  구백  마흔  네  개에 (네개의)  이번 (입원)  병상을  확중해 (확충해)  하루  확진  만  만명해도 (명에도)  대응하겠다는  목표니다 (목표입니다)
# N CORRECT   : 53
# N DELETE    : 2
# N SUBSTITUTE: 26
# N INSERT    : 8
# WER: 0.444

# %%
import json
try:
  import editdistance
except:
  # !pip install editdistance
  import editdistance
from typing import List

def word_error_rate(hypotheses: List[str], references: List[str], use_cer=False) -> float:
    """
    Computes Average Word Error rate between two texts represented as
    corresponding lists of string. Hypotheses and references must have same
    length.
    Args:
      hypotheses: list of hypotheses
      references: list of references
      use_cer: bool, set True to enable cer
    Returns:
      (float) average word error rate
    """
    scores = 0
    words = 0
    if len(hypotheses) != len(references):
        raise ValueError(
            "In word error rate calculation, hypotheses and reference"
            " lists must have the same number of elements. But I got:"
            "{0} and {1} correspondingly".format(len(hypotheses), len(references))
        )
    for h, r in zip(hypotheses, references):
        if use_cer:
            h_list = list(h)
            r_list = list(r)
        else:
            h_list = h.split()
            r_list = r.split()
        words += len(r_list)
        scores += editdistance.eval(h_list, r_list)
    if words != 0:
        wer = 1.0 * scores / words
    else:
        wer = float('inf')
    return wer


def move_dimension_to_the_front(tensor, dim_index):
    all_dims = list(range(tensor.ndim))
    return tensor.permute(*([dim_index] + all_dims[:dim_index] + all_dims[dim_index + 1 :]))



#@title Calculate WER or CER for output transcript file { run: "auto" }
use_cer = False #@param {type:"boolean"}
manifest_path = "/content/1_kspon_eval_clean_output_character_20_202_ksponspeech.json" #@param {type: "string"}


ground_truth_text = []
predicted_text = []
invalid_manifest = False

ground_truth_text = []
predicted_text = []
invalid_manifest = False
with open(manifest_path, 'r', encoding='utf-8') as f:
  for line in f:
      data = json.loads(line)

      if 'pred_text' not in data:
          invalid_manifest = True
          break
      ground_truth_text.append(data['text'])
      predicted_text.append(data['pred_text'])

# Test for invalid manifest supplied
if invalid_manifest:
    raise ValueError(
        f"Invalid manifest provided: {manifest_path} does not "
        f"contain value for `pred_text`."
    )



metric_name = 'CER' if use_cer else 'WER'
metric_value = word_error_rate(hypotheses=predicted_text, references=ground_truth_text, use_cer=use_cer)
print(metric_value)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0.1945144407830975

# %%
use_cer = True
metric_name = 'CER' if use_cer else 'WER'
metric_value = word_error_rate(hypotheses=predicted_text, references=ground_truth_text, use_cer=use_cer)
print("CER: ",metric_value)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0.06909035362407394

# %%
del_count = 0
sub_count = 0
insert_count = 0
total_wer = 0

for idx, (ref, hyp) in enumerate(zip(ground_truth_text[500: 900], predicted_text[500: 900])):
  print(colored(0, 0, 0, f"{idx} ---------------"))
  print(colored(0, 0, 0, f"REF: {ref}"))
  print(colored(0, 0, 0, f"HYP: {hyp}"))
  output, compares = wer(ref, hyp ,debug=True)
  print("")
  metric_value = word_error_rate(hypotheses=[hyp], references=[ref], use_cer=True)
  print(colored(0, 0, 0, f"WER: {output['WER']}  | CER: {metric_value}"))
  print()
  
  del_count += output['Cor']
  sub_count += output['Sub']
  insert_count += output['Ins']
  total_wer += output['WER']

print(colored(255, 0, 0, f"N DELETE    : {del_count}"))
print(colored(0, 255, 0, f"N SUBSTITUTE: {sub_count}"))
print(colored(0, 0, 255, f"N INSERT    : {insert_count}"))
print(colored(0, 0, 0, f"WER: {total_wer / 500}"))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0 ---------------
# REF: 얼 얼마 주는데
# HYP: 얼 얼마 줬는데
# 얼  얼마  줬는데 (주는데)
# WER: 0.333  | CER: 0.125
#
# 1 ---------------
# REF: 이제 그냥 졸업
# HYP: 이제 그냥 졸업
# 이제  그냥  졸업
# WER: 0.0  | CER: 0.0
#
# 2 ---------------
# REF: 글썽거리면서 봤었지
# HYP: 글썽 거리면서 봤었지
# 글썽  거리면서 (글썽거리면서)  봤었지
# WER: 1.0  | CER: 0.1
#
# 3 ---------------
# REF: 그런 거 상관 없는 거 같던데 까 뭐 서로 인사를 시킨 게 아니라 뭐 엄마 나 남자친구 생겼어 어 그래 얼른 결혼해 약간 이런 거야
# HYP: 그런 거 상관없는 거 같던데 까 뭐 서로 인사를 시킨 게 아니라 어 뭐 엄마 나 남자 친구 생겼어 어 그럼 원래 결혼해 약간 이런 거야
# 그런  거  상관  상관없는 (없는)  거  같던데  까  뭐  서로  인사를  시킨  게  아니라  어  뭐  엄마  나  남자  친구 (남자친구)  생겼어  어  그럼 (그래)  원래 (얼른)  결혼해  약간  이런  거야
# WER: 0.28  | CER: 0.0958904109589041
#
# 4 ---------------
# REF: 그루거 하면서 무상거주에서 벗어났으니까 그 토지가 있는 걸로 잡혀서 세금이 오른 거야
# HYP: 그르거 하면서 무상거주에서 벗어났으니까 그 토지가 있는 걸로 잡혀서 세금이 오른 거야
# 그르거 (그루거)  하면서  무상거주에서  벗어났으니까  그  토지가  있는  걸로  잡혀서  세금이  오른  거야
# WER: 0.083  | CER: 0.02127659574468085
#
# 5 ---------------
# REF: 그래서 교수도 해 보고 싶고 나중에 나이가 들어서 만약에 배우 생활을 못 하면
# HYP: 그래서 교수도 해보고 싶고 나중에 나이가 들어서 만약에 배우 생활을 못 하면
# 그래서  교수도  해  해보고 (보고)  싶고  나중에  나이가  들어서  만약에  배우  생활을  못  하면
# WER: 0.154  | CER: 0.023255813953488372
#
# 6 ---------------
# REF: 그 다시보니까 내용이 생각이 안나가지고
# HYP: 다시 보니까 내용이 생각이 안 나가지고
# 다시 (그)  보니까 (다시보니까)  내용이  생각이  안  나가지고 (안나가지고)
# WER: 0.8  | CER: 0.19047619047619047
#
# 7 ---------------
# REF: 도저히 멈출 수가 없어 거의 폭주기관차야 걔는
# HYP: 도저히 멈출 수가 없어 거의 폭죽 기간 차야 걔는
# 도저히  멈출  수가  없어  거의  폭죽  기간  차야 (폭주기관차야)  걔는
# WER: 0.429  | CER: 0.16
#
# 8 ---------------
# REF: 뎃 아니 근데 아 나 왜 너무 많은 도움을 받아서 또 일어나라하기 좀 그래
# HYP: 아니 근데 아 나 너무 많은 도움을 받아서 또 일어나라 하기 좀 그래
# 뎃  아니  근데  아  나  왜  너무  많은  도움을  받아서  또  일어나라  하기 (일어나라하기)  좀  그래
# WER: 0.286  | CER: 0.12195121951219512
#
# 9 ---------------
# REF: 아니 깨운하진 않아
# HYP: 깨운하진 않아
# 아니  깨운하진  않아
# WER: 0.333  | CER: 0.3
#
# 10 ---------------
# REF: 근데 첫날 이튿 날 해 봤는데 너무 힘든 거야 내가 내가 도저히 이 포스기를 외울 수 없을 것 같다 라고 생각을 했어 과장님한테 전화를 드렸어 나는 제
# HYP: 근데 첫날 이틀날 해봤는데 너무 힘든 거야 내가 내가 도저히 이 포스기를 외울 수 없을 거 같다라고 생각을 했어 과장님한테 전화를 드렸어 나는 데
# 근데  첫날  이튿  날  이틀날 (해)  해봤는데 (봤는데)  너무  힘든  거야  내가  내가  도저히  이  포스기를  외울  수  없을  것  거 (같다)  같다라고 (라고)  생각을  했어  과장님한테  전화를  드렸어  나는  데 (제)
# WER: 0.296  | CER: 0.07142857142857142
#
# 11 ---------------
# REF: 아 근데 솔직히 그 두 친구가 나보다 공부를 더 잘했는데
# HYP: 그니까 아 근데 솔직히 그 두 친구가 나보다 공부를 더 잘했는데
# 그니까  아  근데  솔직히  그  두  친구가  나보다  공부를  더  잘했는데
# WER: 0.1  | CER: 0.12903225806451613
#
# 12 ---------------
# REF: 뮤지컬과들이 재능이 많은 사람들이 많아가지구 진짜 노래를 진짜 엄청 잘 해 그래서
# HYP: 뮤지컬과들이 재능이 많은 사람들이 많아가지구 진짜 노래를 진짜 엄청 잘해 그래서
# 뮤지컬과들이  재능이  많은  사람들이  많아가지구  진짜  노래를  진짜  엄청  잘  잘해 (해)  그래서
# WER: 0.167  | CER: 0.022222222222222223
#
# 13 ---------------
# REF: 응 그치
# HYP: 그치
# 응  그치
# WER: 0.5  | CER: 0.5
#
# 14 ---------------
# REF: 사람마다 다른건가
# HYP: 사람마다 다른 건가
# 사람마다  다른  건가 (다른건가)
# WER: 1.0  | CER: 0.1111111111111111
#
# 15 ---------------
# REF: 다음에 봐야지
# HYP: 당해봐야지
# 다음에  당해봐야지 (봐야지)
# WER: 1.0  | CER: 0.5714285714285714
#
# 16 ---------------
# REF: 무조건 입어야 돼
# HYP: 무조건 입어야 돼
# 무조건  입어야  돼
# WER: 0.0  | CER: 0.0
#
# 17 ---------------
# REF: 안 가 안 가 안 썼어 아예
# HYP: 안 가 안 가 안 썼어 아예
# 안  가  안  가  안  썼어  아예
# WER: 0.0  | CER: 0.0
#
# 18 ---------------
# REF: 일단 택시를 타고 가서 하던 걸 하자
# HYP: 일단 택시를 타고 가서 하던 걸 하자
# 일단  택시를  타고  가서  하던  걸  하자
# WER: 0.0  | CER: 0.0
#
# 19 ---------------
# REF: 뭐 프록
# HYP: 어 프레
# 어 (뭐)  프레 (프록)
# WER: 1.0  | CER: 0.5
#
# 20 ---------------
# REF: 에 에 에 이제 옛날이면 자신있게 자기 막 잘하고 그랬는데 이제 그런 것도 없고 그냥 무조건 그냥 반만 가는 챔피언 버스 타는 챔피언
# HYP: 애 옛 이제 옛날에는 자신 있게 자기 막 잘하고 그랬는데 이제 그런 것도 없고 그냥 무조건 그냥 반만 가는 챔피언 버스 타는 챔피언
# 애 (에)  옛 (에)  이제 (에)  옛날에는 (이제)  자신 (옛날이면)  있게 (자신있게)  자기  막  잘하고  그랬는데  이제  그런  것도  없고  그냥  무조건  그냥  반만  가는  챔피언  버스  타는  챔피언
# WER: 0.261  | CER: 0.0945945945945946
#
# 21 ---------------
# REF: 초록색이 너무 많이 나와 그게 효과가 너무 좋아서 너무 많이 나와
# HYP: 그 초록색이 너무 많이 나와 그게 효과가 너무 좋아서 너무 많이 나와
# 그  초록색이  너무  많이  나와  그게  효과가  너무  좋아서  너무  많이  나와
# WER: 0.091  | CER: 0.05555555555555555
#
# 22 ---------------
# REF: 항아리 채 드셨기 때문에 예 아 근데 뭐 저도 너무 공감합니다 저도 인제 저는
# HYP: 할아리체 드셨기 때문에 예 아 근데 뭐 저도 너무 공감합니다 저도 인제 저는
# 항아리  할아리체 (채)  드셨기  때문에  예  아  근데  뭐  저도  너무  공감합니다  저도  인제  저는
# WER: 0.143  | CER: 0.06976744186046512
#
# 23 ---------------
# REF: 그리고 또 다른 잘나가는 교수 있는데
# HYP: 그리고 또 따른 잘 나가는 교육수 있는데
# 그리고  또  따른  잘 (다른)  나가는 (잘나가는)  교육수 (교수)  있는데
# WER: 0.667  | CER: 0.15
#
# 24 ---------------
# REF: 카페 카페 재밌을 거 같은데
# HYP: 카페 카페 재밌을 거 같은데
# 카페  카페  재밌을  거  같은데
# WER: 0.0  | CER: 0.0
#
# 25 ---------------
# REF: 엄청 많이 먹고 왔구만
# HYP: 엄청 많이 먹고 왔고만
# 엄청  많이  먹고  왔고만 (왔구만)
# WER: 0.25  | CER: 0.08333333333333333
#
# 26 ---------------
# REF: 약간 뭐라해야 되지 몰라 설명할 수 없어
# HYP: 약간 뭐라 해야 되지 몰라 설명할 수 없어
# 약간  뭐라  해야 (뭐라해야)  되지  몰라  설명할  수  없어
# WER: 0.286  | CER: 0.045454545454545456
#
# 27 ---------------
# REF: 뭐 자기만 아는 것도 있고 앞에서 형식적으로만 하는 것도 있다보니까 그냥 나도 그냥 똑같이 그냥 형식적으로 이케 변하는 거 같애
# HYP: 뭐 자기만 아는 것도 있고 앞에서 형식적으로만 하는 것도 있다 보니까 그냥 나도 그냥 똑같이 그냥 형식적으로 개 변하는 거 같애
# 뭐  자기만  아는  것도  있고  앞에서  형식적으로만  하는  것도  있다  보니까 (있다보니까)  그냥  나도  그냥  똑같이  그냥  형식적으로  개 (이케)  변하는  거  같애
# WER: 0.15  | CER: 0.04225352112676056
#
# 28 ---------------
# REF: 만토피아가 최고지
# HYP: 만토피아가 최고지
# 만토피아가  최고지
# WER: 0.0  | CER: 0.0
#
# 29 ---------------
# REF: 가야 되는데 돈이 모일까
# HYP: 가야 되는데 돈이 모일까
# 가야  되는데  돈이  모일까
# WER: 0.0  | CER: 0.0
#
# 30 ---------------
# REF: 뭐 있지 그거
# HYP: 뭐 있지 어
# 뭐  있지  어 (그거)
# WER: 0.333  | CER: 0.2857142857142857
#
# 31 ---------------
# REF: 그래서 그것도 뭐 교학팀 근데 교학팀이 진짜 진짜 진짜 멍청해
# HYP: 그래서 그것도 뭐 교학팀 근데 교양 팀이 진짜 진짜 진짜 멍청해
# 그래서  그것도  뭐  교학팀  근데  교양  팀이 (교학팀이)  진짜  진짜  진짜  멍청해
# WER: 0.2  | CER: 0.058823529411764705
#
# 32 ---------------
# REF: 없어서 못 먹지 다 잘먹지 뭐
# HYP: 없어서 못 먹대 다 잘 먹지 뭐
# 없어서  못  먹대 (먹지)  다  잘  먹지 (잘먹지)  뭐
# WER: 0.5  | CER: 0.125
#
# 33 ---------------
# REF: 좀 많이 지치더라구
# HYP: 좀 많이 지치더라구
# 좀  많이  지치더라구
# WER: 0.0  | CER: 0.0
#
# 34 ---------------
# REF: 그 다음에 아 너 혼자 온 적이 없어 혼자 온다 했는데 안 왔잖아
# HYP: 그다음에 아 너 혼자 온 적이 없어 혼자 온다 했는데 안 왔잖아
# 그  그다음에 (다음에)  아  너  혼자  온  적이  없어  혼자  온다  했는데  안  왔잖아
# WER: 0.154  | CER: 0.027777777777777776
#
# 35 ---------------
# REF: 어 어 그 어 그렇지
# HYP: 어 어 그 어 그렇지
# 어  어  그  어  그렇지
# WER: 0.0  | CER: 0.0
#
# 36 ---------------
# REF: 우리도 그랬어
# HYP: 우리도 그랬어
# 우리도  그랬어
# WER: 0.0  | CER: 0.0
#
# 37 ---------------
# REF: 밥 먹었어
# HYP: 밥 먹었어
# 밥  먹었어
# WER: 0.0  | CER: 0.0
#
# 38 ---------------
# REF: 그래서 그냥
# HYP: 그서 그냥
# 그서 (그래서)  그냥
# WER: 0.5  | CER: 0.16666666666666666
#
# 39 ---------------
# REF: 혹시 한국 배우 말고 또 외국에서 좋아하는 배우 있으세요
# HYP: 혹시 한국 배우 말고 또 외국에서 좋아하는 배우 이 있으세요
# 혹시  한국  배우  말고  또  외국에서  좋아하는  배우  이  있으세요
# WER: 0.111  | CER: 0.06451612903225806
#
# 40 ---------------
# REF: 북미정상회담이
# HYP: 북미 정상회담이
# 북미  정상회담이 (북미정상회담이)
# WER: 2.0  | CER: 0.14285714285714285
#
# 41 ---------------
# REF: 안 놀아
# HYP: 안 놀아
# 안  놀아
# WER: 0.0  | CER: 0.0
#
# 42 ---------------
# REF: 응 너나 잘 해
# HYP: 응 너나 잘해
# 응  너나  잘  잘해 (해)
# WER: 0.5  | CER: 0.125
#
# 43 ---------------
# REF: 오만 원
# HYP: 오만 원
# 오만  원
# WER: 0.0  | CER: 0.0
#
# 44 ---------------
# REF: 아 시사 그것도 이제 조금씩 읽고
# HYP: 아 시사 그것도 이제 조금씩 읽고
# 아  시사  그것도  이제  조금씩  읽고
# WER: 0.0  | CER: 0.0
#
# 45 ---------------
# REF: 그래서 나랑 같이 하던 사람들이 다 팔백이 목표였거든
# HYP: 그래서 나랑 같이하던 사람들이 다 팔백이 목표였거든
# 그래서  나랑  같이  같이하던 (하던)  사람들이  다  팔백이  목표였거든
# WER: 0.25  | CER: 0.034482758620689655
#
# 46 ---------------
# REF: 아 긋 아니 근데 나는 사실
# HYP: 아이 그 아니 근데 나는 사실
# 아이 (아)  그 (긋)  아니  근데  나는  사실
# WER: 0.333  | CER: 0.13333333333333333
#
# 47 ---------------
# REF: 걔랑은 연락 안 하지
# HYP: 걔랑은 연락 안 하지
# 걔랑은  연락  안  하지
# WER: 0.0  | CER: 0.0
#
# 48 ---------------
# REF: 응 하여튼 그래서 그래서 결혼 얘기를 했나
# HYP: 하여튼 그래서 그래서 결혼 얘기를 했나
# 응  하여튼  그래서  그래서  결혼  얘기를  했나
# WER: 0.143  | CER: 0.08695652173913043
#
# 49 ---------------
# REF: 약간 군대에서 니 위 내 아래로 다 모여 이런 거 같은 거네
# HYP: 약간 군대에서 니 위 내 아래로 다 보여 이런 거 같은 거네
# 약간  군대에서  니  위  내  아래로  다  보여 (모여)  이런  거  같은  거네
# WER: 0.083  | CER: 0.030303030303030304
#
# 50 ---------------
# REF: 스토컨데
# HYP: 스토컨데
# 스토컨데
# WER: 0.0  | CER: 0.0
#
# 51 ---------------
# REF: 응 자취 할 때가 없어 거기 주변에
# HYP: 응 잘 찰 데가 없어 거기 주변에
# 응  잘 (자취)  찰 (할)  데가 (때가)  없어  거기  주변에
# WER: 0.429  | CER: 0.21052631578947367
#
# 52 ---------------
# REF: 갈 수 있으면 나도 이제 사람들이 많이 다니는 쪽 뭐 사람들이 아 정말 갔다와서 좋 좋다
# HYP: 갈 수 있으면 나도 이제 사람들이 많이 다니는 쪽 뭐 사람들이 아 정말 갔다 와서 좋 좋다
# 갈  수  있으면  나도  이제  사람들이  많이  다니는  쪽  뭐  사람들이  아  정말  갔다  와서 (갔다와서)  좋  좋다
# WER: 0.125  | CER: 0.02040816326530612
#
# 53 ---------------
# REF: 계속 수업을 듣는데 두 시간 내내 눈이 마주치는 거야
# HYP: 그래서 수업을 듣는데 두 시간 내내 눈이 마주치는 거야
# 그래서 (계속)  수업을  듣는데  두  시간  내내  눈이  마주치는  거야
# WER: 0.111  | CER: 0.10344827586206896
#
# 54 ---------------
# REF: 살 거 면은 미리 주문을 해야 돼
# HYP: 살 거면은 미리 주문을 해야 돼
# 살  거  거면은 (면은)  미리  주문을  해야  돼
# WER: 0.286  | CER: 0.05555555555555555
#
# 55 ---------------
# REF: 그래서 만약에 칼하트 같은 것도 인터넷에서 한번 보고
# HYP: 그래서 만약에 일단 카라트 같은 것도 인터넷에서 한번 보고
# 그래서  만약에  일단  카라트 (칼하트)  같은  것도  인터넷에서  한번  보고
# WER: 0.25  | CER: 0.1724137931034483
#
# 56 ---------------
# REF: 걱정 많이 할 거 같긴 한데 어
# HYP: 걱정 많이 할 거 같긴 한데 어
# 걱정  많이  할  거  같긴  한데  어
# WER: 0.0  | CER: 0.0
#
# 57 ---------------
# REF: 이제 거기서 좀 느끼는 바가 있어서 그냥
# HYP: 이제 거기서 이제 쫌 느끼는 바가 있어서 그냥
# 이제  거기서  이제  쫌 (좀)  느끼는  바가  있어서  그냥
# WER: 0.286  | CER: 0.18181818181818182
#
# 58 ---------------
# REF: 신교대에서 뭐 그런 거 아 없지 않아 신교대에서
# HYP: 신교대에서 뭐 그런 거 아 없지 않아 신교대에서
# 신교대에서  뭐  그런  거  아  없지  않아  신교대에서
# WER: 0.0  | CER: 0.0
#
# 59 ---------------
# REF: 아니야 고등학교 때도 한자 했잖아
# HYP: 아야 고등학교 때도 한자 했잖아
# 아야 (아니야)  고등학교  때도  한자  했잖아
# WER: 0.2  | CER: 0.05555555555555555
#
# 60 ---------------
# REF: 그 동네마냥 둔산동 갈꺼야
# HYP: 동네만이야 둔산동 갈 거야
# 동네만이야 (그)  둔산동 (동네마냥)  갈 (둔산동)  거야 (갈꺼야)
# WER: 1.0  | CER: 0.5
#
# 61 ---------------
# REF: 커트를 하고 그 저는 가장 좋은 입시 시스템이 서울 예술 대학교인 거 같애요
# HYP: 커트를 하고 그 저는 가장 좋은 입시 시스템이 서울예술대학교인 거 같애요
# 커트를  하고  그  저는  가장  좋은  입시  시스템이  서울  예술  서울예술대학교인 (대학교인)  거  같애요
# WER: 0.231  | CER: 0.047619047619047616
#
# 62 ---------------
# REF: 말도 안 돼
# HYP: 말도 안 돼
# 말도  안  돼
# WER: 0.0  | CER: 0.0
#
# 63 ---------------
# REF: 그 보드는 처음 탄 거야
# HYP: 금 보드는 처음 탄 거야
# 금 (그)  보드는  처음  탄  거야
# WER: 0.2  | CER: 0.07692307692307693
#
# 64 ---------------
# REF: 그거 진짜 좋아
# HYP: 그거 진짜 좋아
# 그거  진짜  좋아
# WER: 0.0  | CER: 0.0
#
# 65 ---------------
# REF: 기억나는 사람들은 다 접어봤다 하다 못 해 그 사람까지
# HYP: 기억나는 사람들 다 접어봤다 하다못해 그 사람까지
# 기억나는  사람들 (사람들은)  다  접어봤다  하다  못  하다못해 (해)  그  사람까지
# WER: 0.444  | CER: 0.1
#
# 66 ---------------
# REF: 조깅한다고
# HYP: 뒤에 조깅한다고
# 뒤에  조깅한다고
# WER: 1.0  | CER: 0.6
#
# 67 ---------------
# REF: 근데 뮤지컬과는 연극영화과보다는 더 쩍거든 그래도 많긴 하잖아 근데
# HYP: 근데 뮤지컬과는 연극영화과보다는 더 쩍거든 그래도 많긴 하잖아 근데
# 근데  뮤지컬과는  연극영화과보다는  더  쩍거든  그래도  많긴  하잖아  근데
# WER: 0.0  | CER: 0.0
#
# 68 ---------------
# REF: 일단 항공과 너 페이스북 보면은 대부분 막 똥군기다 뭐다 그렇게 잡는 거 있잖아 그거 때문에도 싫고
# HYP: 일단 항공과 너 페이스북 보면은 대부분 막 똥 군기다 뭐다 그렇게 잡는 거 있잖아 그거 때문에도 싫고
# 일단  항공과  너  페이스북  보면은  대부분  막  똥  군기다 (똥군기다)  뭐다  그렇게  잡는  거  있잖아  그거  때문에도  싫고
# WER: 0.125  | CER: 0.01818181818181818
#
# 69 ---------------
# REF: 근데 이번에는 우리 캠핑 가는 것도 좀 생각해서 사는 게 나을 것 같애
# HYP: 이번에는 우리 캠핑가는 것도 좀 생각해서 하는 게 나을 거 같애
# 근데  이번에는  우리  캠핑  캠핑가는 (가는)  것도  좀  생각해서  하는 (사는)  게  나을  거 (것)  같애
# WER: 0.385  | CER: 0.15384615384615385
#
# 70 ---------------
# REF: 그냥 약간 일상처럼
# HYP: 그냥 약간 일상처럼
# 그냥  약간  일상처럼
# WER: 0.0  | CER: 0.0
#
# 71 ---------------
# REF: 그런 각서 같은 거 쓰는 데 있잖아
# HYP: 그런 각서 같은 거 쓰는 데 있잖아
# 그런  각서  같은  거  쓰는  데  있잖아
# WER: 0.0  | CER: 0.0
#
# 72 ---------------
# REF: 그 뭐든지 해보는 건 좋은 거 같애 나도 이것저것 많이 안 해본 게 많아서 나 같은 경우는 해외는 딱 한 번 대마도 한 번 갔다왔거든 일본에 있는 대마도를 갔다왔는데
# HYP: 까 뭐든지 해보는 건 좋은 거 같애 나도 이것저것 많이 안 해본 게 많아서 나 같은 경우는 해외는 딱 한 번 대마도 한 번 갔다 왔거든 일본에 있는 대마도로 갔다 왔는데
# 까 (그)  뭐든지  해보는  건  좋은  거  같애  나도  이것저것  많이  안  해본  게  많아서  나  같은  경우는  해외는  딱  한  번  대마도  한  번  갔다  왔거든 (갔다왔거든)  일본에  있는  대마도로  갔다 (대마도를)  왔는데 (갔다왔는데)
# WER: 0.207  | CER: 0.043478260869565216
#
# 73 ---------------
# REF: 내년에
# HYP: 내년에
# 내년에
# WER: 0.0  | CER: 0.0
#
# 74 ---------------
# REF: 그래서 내가 거기를 갔다 오니까 그냥 조금 내려놓음이 된다고 해야되나 약간
# HYP: 그래서 내가 거기를 갔다 오니까 그냥 쪼끔 내려놓음이 된다고 해야 되나 약간
# 그래서  내가  거기를  갔다  오니까  그냥  쪼끔 (조금)  내려놓음이  된다고  해야  되나 (해야되나)  약간
# WER: 0.273  | CER: 0.07317073170731707
#
# 75 ---------------
# REF: 미친 거 아니야
# HYP: 미친 거 아니야
# 미친  거  아니야
# WER: 0.0  | CER: 0.0
#
# 76 ---------------
# REF: 그니까 그럼
# HYP: 그니까 그럼
# 그니까  그럼
# WER: 0.0  | CER: 0.0
#
# 77 ---------------
# REF: 그런데 이제 처음에는 이제 어디 어디 살았는지 모르고 제가
# HYP: 근데 이제 처음에는 이제 어디 어디 살았는지 모르고 제가
# 근데 (그런데)  이제  처음에는  이제  어디  어디  살았는지  모르고  제가
# WER: 0.111  | CER: 0.0625
#
# 78 ---------------
# REF: 보호대가 의미가 없잖아
# HYP: 보호대가 의미가 없잖아
# 보호대가  의미가  없잖아
# WER: 0.0  | CER: 0.0
#
# 79 ---------------
# REF: 자의식이라고 생각하기 때문에 또 자의식 그리고 세 번째는 일맥상통한데 저도 성실함 게으르면 안 돼요 어떤 일이든 배우를 떠나서 게으르면 끝이기 때문에 뭐
# HYP: 자의식이라고 생각하기 때문에 또 자의식 그리고 세 번째는 일맥 상통 한대 저도 성실함 게으름이 안 돼요 어떤 일이든 배우를 떠나서 게으르면 끝이기 때문에 뭐
# 자의식이라고  생각하기  때문에  또  자의식  그리고  세  번째는  일맥  상통  한대 (일맥상통한데)  저도  성실함  게으름이 (게으르면)  안  돼요  어떤  일이든  배우를  떠나서  게으르면  끝이기  때문에  뭐
# WER: 0.182  | CER: 0.058823529411764705
#
# 80 ---------------
# REF: 칠만 원
# HYP: 칠만 원
# 칠만  원
# WER: 0.0  | CER: 0.0
#
# 81 ---------------
# REF: 동영상만 꼐속 꼐속 똑같은 거 또 보고 또 보고 또 보고 그랬어 진짜 지루해가지고 근데 그걸 또 졸면은 그 뒤에 또
# HYP: 동영상만 계속 계속 똑같은 거 또 보고 또 보고 또 보고 그랬어 진짜 지루해가지구 근데 그걸 또 졸면은 그 뒤에 또
# 동영상만  계속 (꼐속)  계속 (꼐속)  똑같은  거  또  보고  또  보고  또  보고  그랬어  진짜  지루해가지구 (지루해가지고)  근데  그걸  또  졸면은  그  뒤에  또
# WER: 0.143  | CER: 0.046875
#
# 82 ---------------
# REF: 근데 그건 그렇지 근데 그래도 뭔가
# HYP: 근데 그건 그렇지 근데 그래도 뭔가
# 근데  그건  그렇지  근데  그래도  뭔가
# WER: 0.0  | CER: 0.0
#
# 83 ---------------
# REF: 워크숍
# HYP: 먹고
# 먹고 (워크숍)
# WER: 1.0  | CER: 1.0
#
# 84 ---------------
# REF: 만약에
# HYP: 만약에
# 만약에
# WER: 0.0  | CER: 0.0
#
# 85 ---------------
# REF: 아니야 할 수 있어
# HYP: 아니야 할 수 있어
# 아니야  할  수  있어
# WER: 0.0  | CER: 0.0
#
# 86 ---------------
# REF: 이번 학기 다니고 다음 학기 때 쉴 때 이제 그 여름방학기 시작되잖아
# HYP: 이번 학기 다니고 다음 학기 때 쉴 때 이제 그 여름방학이 시작되잖아
# 이번  학기  다니고  다음  학기  때  쉴  때  이제  그  여름방학이 (여름방학기)  시작되잖아
# WER: 0.083  | CER: 0.02631578947368421
#
# 87 ---------------
# REF: 여의도 하면 나 그것밖에 생각 안 나
# HYP: 여의도 하면 나 그거밖에 생각 안 나
# 여의도  하면  나  그거밖에 (그것밖에)  생각  안  나
# WER: 0.143  | CER: 0.05
#
# 88 ---------------
# REF: 우리는 입시를 할 때
# HYP: 우리는 입시를 할 때
# 우리는  입시를  할  때
# WER: 0.0  | CER: 0.0
#
# 89 ---------------
# REF: 어떻게 그 부분을 이제 받아들이고 오히려 일본에 가서 그 공부를 하고 싶다고 계획을 하셨는지
# HYP: 어떻게 그 부분을 이제 받아들이고 오히려 일본에 가서 그 공부를 하고 싶다고 이제 계획을 하셨는지
# 어떻게  그  부분을  이제  받아들이고  오히려  일본에  가서  그  공부를  하고  싶다고  이제  계획을  하셨는지
# WER: 0.071  | CER: 0.058823529411764705
#
# 90 ---------------
# REF: 아는 친척 결혼식장이구나 하고서 이렇게 갔는데
# HYP: 아는 친척 결혼식장이구나 하고서 이렇게 갔는데
# 아는  친척  결혼식장이구나  하고서  이렇게  갔는데
# WER: 0.0  | CER: 0.0
#
# 91 ---------------
# REF: 영어 공부해서 가야지
# HYP: 영어 공부해서 가야지
# 영어  공부해서  가야지
# WER: 0.0  | CER: 0.0
#
# 92 ---------------
# REF: 그래 이렇게 생각한다니까 나이가 있으니까 해야 된다
# HYP: 그래 이렇게 생각한다니까 나이가 있으니까 해야 된다
# 그래  이렇게  생각한다니까  나이가  있으니까  해야  된다
# WER: 0.0  | CER: 0.0
#
# 93 ---------------
# REF: 그 거기서 만난 애
# HYP: 그 거기서 만난 애
# 그  거기서  만난  애
# WER: 0.0  | CER: 0.0
#
# 94 ---------------
# REF: 그치 그치 그때 가면 이제
# HYP: 그치 그치 그때 가면 이제
# 그치  그치  그때  가면  이제
# WER: 0.0  | CER: 0.0
#
# 95 ---------------
# REF: 아 알죠
# HYP: 아 알죠
# 아  알죠
# WER: 0.0  | CER: 0.0
#
# 96 ---------------
# REF: 어 저번에 보니까는 경쟁률도 높지 않은거 같고 그냥 신청만 하면 거의 다 되는 거 같았어
# HYP: 어 뭐 저번에 보니까는 경쟁률도 높지 않은 거 같고 그냥 신청만 하면은 거의 다 되는 거 같았어
# 어  뭐  저번에  보니까는  경쟁률도  높지  않은  거 (않은거)  같고  그냥  신청만  하면은 (하면)  거의  다  되는  거  같았어
# WER: 0.267  | CER: 0.08163265306122448
#
# 97 ---------------
# REF: 오늘 너 얘기 하나도 안 나왔는데
# HYP: 어 너 얘기 하나도 안 나왔는데
# 어 (오늘)  너  얘기  하나도  안  나왔는데
# WER: 0.167  | CER: 0.1111111111111111
#
# 98 ---------------
# REF: 뭐 뭐 누가 보호할래 마티츠 빼고 이게 포그바랑 에레라가 다 올라가거든 공격 때
# HYP: 뭐 뭐 누가 뭐 할래 마티즈 빼고 이게 포그바랑 에레라가 다 올라가거든 공격대
# 뭐  뭐  누가  뭐  할래 (보호할래)  마티즈 (마티츠)  빼고  이게  포그바랑  에레라가  다  올라가거든  공격  공격대 (때)
# WER: 0.385  | CER: 0.11363636363636363
#
# 99 ---------------
# REF: 나 같은 경우에도 고등학교 들어 갈 때 솔직히
# HYP: 나 같은 경우에도 고등학교 들어갈 때 솔직히
# 나  같은  경우에도  고등학교  들어  들어갈 (갈)  때  솔직히
# WER: 0.25  | CER: 0.04
#
# 100 ---------------
# REF: 그니까
# HYP: 그니까
# 그니까
# WER: 0.0  | CER: 0.0
#
# 101 ---------------
# REF: 어 집에서 다녀야지
# HYP: 어 집에 다녀야지
# 어  집에 (집에서)  다녀야지
# WER: 0.333  | CER: 0.1
#
# 102 ---------------
# REF: 엉 볼 만한 거
# HYP: 어 볼만한 거
# 엉  어 (볼)  볼만한 (만한)  거
# WER: 0.75  | CER: 0.25
#
# 103 ---------------
# REF: 아니 나는 안 봤는데 내 친구가 봤대
# HYP: 아니 나는 안 봤는데 내 친구가 봤대
# 아니  나는  안  봤는데  내  친구가  봤대
# WER: 0.0  | CER: 0.0
#
# 104 ---------------
# REF: 쉐라톤으로 가는 그 밤거리가
# HYP: 세라톤으로 가는 그 밤거리가
# 세라톤으로 (쉐라톤으로)  가는  그  밤거리가
# WER: 0.25  | CER: 0.06666666666666667
#
# 105 ---------------
# REF: 자의식을 버리는 거 누군가 나를 어떻게 보는 거 이거에 대한 것에 해방을 되면은 카메라가 나를 잡을 때 그리고 어 무슨 조연출 감독
# HYP: 자식을 버리는 거 누군가 나를 어떻게 보는 거 이거에 대한 것에 해방을 대면은 카메라가 나를 잡을 때 그리고 어 무슨 조연출 감독
# 자식을 (자의식을)  버리는  거  누군가  나를  어떻게  보는  거  이거에  대한  것에  해방을  대면은 (되면은)  카메라가  나를  잡을  때  그리고  어  무슨  조연출  감독
# WER: 0.091  | CER: 0.0273972602739726
#
# 106 ---------------
# REF: 어 한자 했는데 우리가 공부를 안 한 거지
# HYP: 어 한자 했는데 우리가 공부를 안 한 거지
# 어  한자  했는데  우리가  공부를  안  한  거지
# WER: 0.0  | CER: 0.0
#
# 107 ---------------
# REF: 누구 기억은 안 나고
# HYP: 누구 기억은 안 나고
# 누구  기억은  안  나고
# WER: 0.0  | CER: 0.0
#
# 108 ---------------
# REF: 아니야
# HYP: 아니야
# 아니야
# WER: 0.0  | CER: 0.0
#
# 109 ---------------
# REF: 아니 그건 모르겠어
# HYP: 아니 그건 모르겠어
# 아니  그건  모르겠어
# WER: 0.0  | CER: 0.0
#
# 110 ---------------
# REF: 지금 맨날 술 먹고 놀 때가 아니란 말입니다
# HYP: 지금 맨날 술 먹고 놀 때가 아니란 말입니다
# 지금  맨날  술  먹고  놀  때가  아니란  말입니다
# WER: 0.0  | CER: 0.0
#
# 111 ---------------
# REF: 근데 왜 양쪽에 다 칠갑하고 먹었어
# HYP: 데 왜 양쪽에 다 칠갑하고 먹었어
# 데 (근데)  왜  양쪽에  다  칠갑하고  먹었어
# WER: 0.167  | CER: 0.05263157894736842
#
# 112 ---------------
# REF: 나는 학교 다닐 때 그런 선생 선생님이 없었어 그래가지고
# HYP: 나는 학교 다닐 때 그런 선생 선생님이 없었어 그래가지고
# 나는  학교  다닐  때  그런  선생  선생님이  없었어  그래가지고
# WER: 0.0  | CER: 0.0
#
# 113 ---------------
# REF: 아이 그니까 라운드를 내가 잘못 말했는데
# HYP: 아이 그니까 라운드를 내가 잘못 말했는데
# 아이  그니까  라운드를  내가  잘못  말했는데
# WER: 0.0  | CER: 0.0
#
# 114 ---------------
# REF: 잘 모르겠습니다
# HYP: 잘 모르겠습니다
# 잘  모르겠습니다
# WER: 0.0  | CER: 0.0
#
# 115 ---------------
# REF: 개인 카페가 먼저 그 메뉴도 다양하고 좀 참신함이 덧 밑바탕 되니까 좀 더 사람들을 많이 모을 수 있다고 생각이 들고
# HYP: 개인 카페가 먼저 그 메뉴도 다양하고 좀 참신함이 더 밑바탕 되니까 쫌 더 사람들을 많이 모을 수 있다고 생각이 들고
# 개인  카페가  먼저  그  메뉴도  다양하고  좀  참신함이  더 (덧)  밑바탕  되니까  쫌 (좀)  더  사람들을  많이  모을  수  있다고  생각이  들고
# WER: 0.1  | CER: 0.03076923076923077
#
# 116 ---------------
# REF: 이거 다시 시작해야 되는 거 아니냐 거의
# HYP: 이거 다시 시작해야 되는 거 아니냐 거의
# 이거  다시  시작해야  되는  거  아니냐  거의
# WER: 0.0  | CER: 0.0
#
# 117 ---------------
# REF: 그래갖고 이제 그 길디긴 동영상을 한 두 세 시간인가 봤거든
# HYP: 그래갖고 이제 그 길디 긴 동영상을 한 두 세 시간인가 봤거든
# 그래갖고  이제  그  길디  긴 (길디긴)  동영상을  한  두  세  시간인가  봤거든
# WER: 0.2  | CER: 0.030303030303030304
#
# 118 ---------------
# REF: 아 진짜
# HYP: 아 진짜
# 아  진짜
# WER: 0.0  | CER: 0.0
#
# 119 ---------------
# REF: 어 알죠
# HYP: 어 알죠
# 어  알죠
# WER: 0.0  | CER: 0.0
#
# 120 ---------------
# REF: 지금 나도 휴학 생각하고 있거든 이제 우리학기는 이제 한 학기밖에 쉴 수 있으니까
# HYP: 지금 나도 휴학 생각하고 있거든 이제 우리 학기는 이제 한 학기밖에 쉴 수 있으니까
# 지금  나도  휴학  생각하고  있거든  이제  우리  학기는 (우리학기는)  이제  한  학기밖에  쉴  수  있으니까
# WER: 0.154  | CER: 0.022222222222222223
#
# 121 ---------------
# REF: 아니야
# HYP: 아니야
# 아니야
# WER: 0.0  | CER: 0.0
#
# 122 ---------------
# REF: 그런데 응
# HYP: 그런데 응
# 그런데  응
# WER: 0.0  | CER: 0.0
#
# 123 ---------------
# REF: 그렇지
# HYP: 그치
# 그치 (그렇지)
# WER: 1.0  | CER: 0.6666666666666666
#
# 124 ---------------
# REF: 어 그냥 프로모션이 있는 거야
# HYP: 어 그냥 프로모션이 있는 거야
# 어  그냥  프로모션이  있는  거야
# WER: 0.0  | CER: 0.0
#
# 125 ---------------
# REF: 응 그거 면접
# HYP: 응 그거 면접
# 응  그거  면접
# WER: 0.0  | CER: 0.0
#
# 126 ---------------
# REF: 그냥 미리 알아볼 수도 있는 거고
# HYP: 그냥 미리 알아볼 수도 있는 거고
# 그냥  미리  알아볼  수도  있는  거고
# WER: 0.0  | CER: 0.0
#
# 127 ---------------
# REF: 뭐 상한 음식만 안 먹으면은 뭐 음식가지고 난 그런 거 걸려본 적이 없어
# HYP: 뭐 상한 음식만 안 먹으면은 뭐 음식 가지고 난 그런 거 걸려본 적이 없어
# 뭐  상한  음식만  안  먹으면은  뭐  음식  가지고 (음식가지고)  난  그런  거  걸려본  적이  없어
# WER: 0.154  | CER: 0.025
#
# 128 ---------------
# REF: 영화는 안보셨을 수도 있겠는데
# HYP: 영화는 안 보셨을 수도 있겠는데
# 영화는  안  보셨을 (안보셨을)  수도  있겠는데
# WER: 0.5  | CER: 0.0625
#
# 129 ---------------
# REF: 근데 내가 바로 맞췄더니
# HYP: 그 내가 바로 맞췄더니
# 그 (근데)  내가  바로  맞췄더니
# WER: 0.25  | CER: 0.15384615384615385
#
# 130 ---------------
# REF: 아니 나 타는데
# HYP: 아니 나 타는데
# 아니  나  타는데
# WER: 0.0  | CER: 0.0
#
# 131 ---------------
# REF: 그래도
# HYP: 그래도
# 그래도
# WER: 0.0  | CER: 0.0
#
# 132 ---------------
# REF: 의사 확률인가 의사 그거 막 하는 거 있잖아요
# HYP: 의사 확률인가 의사 그거 막 하는 거 있잖아요
# 의사  확률인가  의사  그거  막  하는  거  있잖아요
# WER: 0.0  | CER: 0.0
#
# 133 ---------------
# REF: 내가 들어줄게
# HYP: 내가 들어줄게
# 내가  들어줄게
# WER: 0.0  | CER: 0.0
#
# 134 ---------------
# REF: 아 약간 거기가 확실히 서울에 가깝고 좀 추운데가 아니니까
# HYP: 아 약간 거기가 확실히 서울에 가깝고 쫌 추운 데가 아니니까
# 아  약간  거기가  확실히  서울에  가깝고  쫌  추운 (좀)  데가 (추운데가)  아니니까
# WER: 0.333  | CER: 0.0625
#
# 135 ---------------
# REF: 저번에 가방 산다고 하지 않았어
# HYP: 저번에 가방 산다고 하지 않았어
# 저번에  가방  산다고  하지  않았어
# WER: 0.0  | CER: 0.0
#
# 136 ---------------
# REF: 미친새끼
# HYP:
# 미친새끼
# WER: 1.0  | CER: 1.0
#
# 137 ---------------
# REF: 어 뭐가 있을지 모르니까
# HYP: 어 뭐가 있을지 모르니까
# 어  뭐가  있을지  모르니까
# WER: 0.0  | CER: 0.0
#
# 138 ---------------
# REF: 근데 조금 오래 걸려 한 일주일
# HYP: 근데 쪼끔 오래 걸려 한 일주일
# 근데  쪼끔 (조금)  오래  걸려  한  일주일
# WER: 0.167  | CER: 0.11764705882352941
#
# 139 ---------------
# REF: 그럼 너 이번에 VIP 되는 거 아니야
# HYP: 그럼 너 이번에 브이아비 되는 거 아니야
# 그럼  너  이번에  브이아비 (VIP)  되는  거  아니야
# WER: 0.143  | CER: 0.19047619047619047
#
# 140 ---------------
# REF: 그리고 또 마지막에 윌이 공부냐 사랑이냐 둘 중에
# HYP: 그리고 또 마지막에 미리 공부냐 사랑이냐 둘 중에
# 그리고  또  마지막에  미리 (윌이)  공부냐  사랑이냐  둘  중에
# WER: 0.125  | CER: 0.07407407407407407
#
# 141 ---------------
# REF: 그리고
# HYP: 그러고
# 그러고 (그리고)
# WER: 1.0  | CER: 0.3333333333333333
#
# 142 ---------------
# REF: 오월드 알바를 하면서 이제 그러고 나서 계속 오월드 알바를 한 오 월 유 월동안 꼐속 했는데
# HYP: 오월드 알바를 하면서 이제 그러고 나서 계속 오월드 알바를 한 오 월 육 월 동안 계속했는데
# 오월드  알바를  하면서  이제  그러고  나서  계속  오월드  알바를  한  오  월  육 (유)  월 (월동안)  동안 (꼐속)  계속했는데 (했는데)
# WER: 0.25  | CER: 0.0784313725490196
#
# 143 ---------------
# REF: 아 근데 거기는 별로 안 추워 어썸은
# HYP: 아 근데 거기는 별로 안 추워 어썸은
# 아  근데  거기는  별로  안  추워  어썸은
# WER: 0.0  | CER: 0.0
#
# 144 ---------------
# REF: 근데 거기서 쪼끔 당황스러운게 뭐냐면 그 어른들이다 보니까 학생들 이렇게 물어보고 이렇게 웃어 주면서 이렇게 설문 조사를 하다 보니까
# HYP: 근데 거기서 쪼끔 당황스러운 게 뭐냐면 그 어른들이다 보니까 학생들이 이렇게 물어보고 이게 웃어주면서 이렇게 설문 수술하다 보니까
# 근데  거기서  쪼끔  당황스러운  게 (당황스러운게)  뭐냐면  그  어른들이다  보니까  학생들이 (학생들)  이렇게  물어보고  이렇게  이게 (웃어)  웃어주면서 (주면서)  이렇게  설문  조사를  수술하다 (하다)  보니까
# WER: 0.421  | CER: 0.10810810810810811
#
# 145 ---------------
# REF: 어 산성동 다른 곳으로 곳으로 아홉살 때 이사를 했는데 그쪽 집에서 지금 스물 다섯 살까지 계속 쭉 살고 있습니다
# HYP: 어 산성동 다른 곳으로 고수로 아홉 살 때 이사를 했는데 그쪽 집에서 지금 스물 다섯 살까지 계속 쭉 살고 있습니다
# 어  산성동  다른  곳으로  고수로  아홉 (곳으로)  살 (아홉살)  때  이사를  했는데  그쪽  집에서  지금  스물  다섯  살까지  계속  쭉  살고  있습니다
# WER: 0.158  | CER: 0.047619047619047616
#
# 146 ---------------
# REF: 그냥 아까 먹은 햄버거 얘기를 하는 게 낫겠어
# HYP: 그냥 아까 먹은 햄버거 얘기를 하는 게 낫겠어
# 그냥  아까  먹은  햄버거  얘기를  하는  게  낫겠어
# WER: 0.0  | CER: 0.0
#
# 147 ---------------
# REF: 엄청 어렸을 때는 이제 대전 어디 지역에 살았는지는
# HYP: 엄청 어렸을 때는 이제 대전 어디 지역에 살았는지는
# 엄청  어렸을  때는  이제  대전  어디  지역에  살았는지는
# WER: 0.0  | CER: 0.0
#
# 148 ---------------
# REF: 어 다까체 쓰고 다까체를 쓰는데 이제 나는 어차피 경험을 하고 와서 알잖아
# HYP: 어 닭가채 쓰고 닭까지를 쓰는데 이제 나는 어차피 경험을 하고 와서 알잖아
# 어  닭가채 (다까체)  쓰고  닭까지를 (다까체를)  쓰는데  이제  나는  어차피  경험을  하고  와서  알잖아
# WER: 0.167  | CER: 0.12195121951219512
#
# 149 ---------------
# REF: 내가 오늘 널 봤잖아
# HYP: 내가 오늘 널 봤잖아
# 내가  오늘  널  봤잖아
# WER: 0.0  | CER: 0.0
#
# 150 ---------------
# REF: 이제 다 같은 입장이다 보니까
# HYP: 이제 다 같은 입장이다 보니까
# 이제  다  같은  입장이다  보니까
# WER: 0.0  | CER: 0.0
#
# 151 ---------------
# REF: 아니 안 먹고 왔어
# HYP: 아니 안 먹고 왔어
# 아니  안  먹고  왔어
# WER: 0.0  | CER: 0.0
#
# 152 ---------------
# REF: 혹시 역사에 관련돼서 영화를 시청하신 것 중에 관람하신 것 중에 혹시 좀 기억에 남는 영화가 있는지 여쭤보고 싶습니다
# HYP: 혹시 역사에 관련돼서 영화를 신청하신 것 중에 관람하신 것 중에 혹시 좀 기억에 남는 영화가 있는지 여쭤보고 싶습니다
# 혹시  역사에  관련돼서  영화를  신청하신 (시청하신)  것  중에  관람하신  것  중에  혹시  좀  기억에  남는  영화가  있는지  여쭤보고  싶습니다
# WER: 0.056  | CER: 0.015384615384615385
#
# 153 ---------------
# REF: 그리고
# HYP: 그리고
# 그리고
# WER: 0.0  | CER: 0.0
#
# 154 ---------------
# REF: 자기 맘대로라
# HYP: 자기 맘대로라
# 자기  맘대로라
# WER: 0.0  | CER: 0.0
#
# 155 ---------------
# REF: 신로마 근데 신로마는 가 보고 싶긴 했는데 어쨌든 기회가 안 돼서 못 갔지만
# HYP: 신로 근데 실로만 가보고 싶긴 했는데 어쨌든 기억 안 돼서 못 갔지만
# 신로 (신로마)  근데  신로마는  실로만 (가)  가보고 (보고)  싶긴  했는데  어쨌든  기억 (기회가)  안  돼서  못  갔지만
# WER: 0.385  | CER: 0.16666666666666666
#
# 156 ---------------
# REF: 이제 나랑 맞는 사람 맞지 않는 사람 있는 것 같애
# HYP: 진짜 나랑 맞는 사람 맞지 않는 사람이 있는 거 같애
# 진짜 (이제)  나랑  맞는  사람  맞지  않는  사람이 (사람)  있는  거 (것)  같애
# WER: 0.3  | CER: 0.14285714285714285
#
# 157 ---------------
# REF: 어 완전 계략인데
# HYP: 어 완전 계략인데
# 어  완전  계략인데
# WER: 0.0  | CER: 0.0
#
# 158 ---------------
# REF: 응 맞아
# HYP: 응 맞어
# 응  맞어 (맞아)
# WER: 0.5  | CER: 0.25
#
# 159 ---------------
# REF: 아 그래 그럼 뭐 오래 쓰겠네 그거 하나 있으면
# HYP: 아 그래 금 뭐 오래 쓰겠네 그거 하나 있으면
# 아  그래  금 (그럼)  뭐  오래  쓰겠네  그거  하나  있으면
# WER: 0.111  | CER: 0.07692307692307693
#
# 160 ---------------
# REF: 그게 예비를 받긴 했는데
# HYP: 그게 예비를 받긴 했는데
# 그게  예비를  받긴  했는데
# WER: 0.0  | CER: 0.0
#
# 161 ---------------
# REF: 그거에 대해서 되게 슬퍼하고 그러다가 다시 이승으로 돌아온거야
# HYP: 그거에 대해서 되게 슬퍼하고 그러다가 다시 이승으로 돌아온 거야
# 그거에  대해서  되게  슬퍼하고  그러다가  다시  이승으로  돌아온  거야 (돌아온거야)
# WER: 0.25  | CER: 0.029411764705882353
#
# 162 ---------------
# REF: 그 다음에
# HYP: 그다음에
# 그  그다음에 (다음에)
# WER: 1.0  | CER: 0.2
#
# 163 ---------------
# REF: 응 사람들 이제 하나씩 하나씩 구해나가는 이런 내용인데
# HYP: 음 사람들 이제 하나씩 하나씩 구해나가는 이런 내용인데
# 음 (응)  사람들  이제  하나씩  하나씩  구해나가는  이런  내용인데
# WER: 0.125  | CER: 0.03333333333333333
#
# 164 ---------------
# REF: 아니 이백 원을 누구 코에 붙여
# HYP: 아니 이백 원을 누구 거에 붙여
# 아니  이백  원을  누구  거에 (코에)  붙여
# WER: 0.167  | CER: 0.058823529411764705
#
# 165 ---------------
# REF: 공부하는 게 더 낫지 않을까 네 해서 이렇게 한 번 일본 유학의 꿈을 키우게 됐습니다 네
# HYP: 공부하는 게 더 낫지 않을까 네 해서 이렇게 한 번 일본 유학에 꿈을 키우게 됐습니다 네
# 공부하는  게  더  낫지  않을까  네  해서  이렇게  한  번  일본  유학에 (유학의)  꿈을  키우게  됐습니다  네
# WER: 0.062  | CER: 0.02040816326530612
#
# 166 ---------------
# REF: 근데 원래 좀 기억 잘 안 나는 거 알지 좀만 지나도
# HYP: 근데 원래 좀 기억 잘 안 나는 거 알지 쫌만 지나도
# 근데  원래  좀  기억  잘  안  나는  거  알지  쫌만 (좀만)  지나도
# WER: 0.091  | CER: 0.034482758620689655
#
# 167 ---------------
# REF: 그래서 나가서 자기도 나간거 같기도 하고
# HYP: 그래서 나가서 자기도 나간 거 같기도 하고
# 그래서  나가서  자기도  나간  거 (나간거)  같기도  하고
# WER: 0.333  | CER: 0.045454545454545456
#
# 168 ---------------
# REF: 나도 좀 그렇게 생각해
# HYP: 응 나도 쫌 그렇게 생각해
# 응  나도  쫌 (좀)  그렇게  생각해
# WER: 0.5  | CER: 0.25
#
# 169 ---------------
# REF: 아 그래
# HYP: 아 그래
# 아  그래
# WER: 0.0  | CER: 0.0
#
# 170 ---------------
# REF: 과연 너무 그냥 준비해간거 위주로 연기를 하는 거면
# HYP: 과연 너무 그냥 준비해 간 거 위주로 연기를 하는 거면
# 과연  너무  그냥  준비해  간  거 (준비해간거)  위주로  연기를  하는  거면
# WER: 0.375  | CER: 0.07142857142857142
#
# 171 ---------------
# REF: 내 생각에는
# HYP: 내 생각에는
# 내  생각에는
# WER: 0.0  | CER: 0.0
#
# 172 ---------------
# REF: 왜냐면 이제
# HYP: 왜냐면 이제
# 왜냐면  이제
# WER: 0.0  | CER: 0.0
#
# 173 ---------------
# REF: 그래서 어제 내가 스키장을 갔다왔는데 스키장에 원래 오 년전 쯤인가 그때 처음 스키를 타고 그때 처음 첫
# HYP: 그래서 어제 내가 스키장을 갔다 왔는데 스키장에 원래 오 년 전쯤인가 그때 처음 스키를 타고 그때 처음 첫
# 그래서  어제  내가  스키장을  갔다  왔는데 (갔다왔는데)  스키장에  원래  오  년 (년전)  전쯤인가 (쯤인가)  그때  처음  스키를  타고  그때  처음  첫
# WER: 0.235  | CER: 0.05172413793103448
#
# 174 ---------------
# REF: 그래서 사실 보러 갈라 했는데 뭔가 안 땡기는 거야 근데 요즘 좋은 영화들 너무 많이 나와가지고 진짜 알리타 봤거든
# HYP: 그래서 사실 보러 갈라 했는데 뭔가 안 땡기는 거야 근데 요즘 좋은 영화들 너무 많이 나와가지구 진짜 알리타 봤거든
# 그래서  사실  보러  갈라  했는데  뭔가  안  땡기는  거야  근데  요즘  좋은  영화들  너무  많이  나와가지구 (나와가지고)  진짜  알리타  봤거든
# WER: 0.053  | CER: 0.015625
#
# 175 ---------------
# REF: 아 너무 일을 많이 시켰구나 연구를
# HYP: 아 너무 일을 많이 시켰구나 연구를
# 아  너무  일을  많이  시켰구나  연구를
# WER: 0.0  | CER: 0.0
#
# 176 ---------------
# REF: 그러면은
# HYP: 그러면은
# 그러면은
# WER: 0.0  | CER: 0.0
#
# 177 ---------------
# REF: 걔 어 걔 전역하기 전까지 취업하기였는데
# HYP: 걔 어 걔 전역하기 전까지 취업하기였는데
# 걔  어  걔  전역하기  전까지  취업하기였는데
# WER: 0.0  | CER: 0.0
#
# 178 ---------------
# REF: 야 진짜 기대하고 있어
# HYP: 아 진짜 기대하고 있어
# 아 (야)  진짜  기대하고  있어
# WER: 0.25  | CER: 0.08333333333333333
#
# 179 ---------------
# REF: 근데 맹장을 짤라 내는 게 아니라 맹장 옆에 붙어 있는 충수 충수굴이라는 게 있어 그
# HYP: 근데 맹장을 짤라내는 게 아니라 맹장 옆에 붙어있는 충 충수 골이라는 게 있어 그
# 근데  맹장을  짤라  짤라내는 (내는)  게  아니라  맹장  옆에  붙어있는 (붙어)  충 (있는)  충수  골이라는 (충수굴이라는)  게  있어  그
# WER: 0.333  | CER: 0.10638297872340426
#
# 180 ---------------
# REF: 일 급이야
# HYP: 일 급이야
# 일  급이야
# WER: 0.0  | CER: 0.0
#
# 181 ---------------
# REF: 진짜 그냥 시간 낭비 같은데
# HYP: 진짜 그냥 시간 낭비 같은데
# 진짜  그냥  시간  낭비  같은데
# WER: 0.0  | CER: 0.0
#
# 182 ---------------
# REF: 아 그거는 그냥 시설에서 주는 건가
# HYP: 아 그거는 그냥 시설에서 주는 건가
# 아  그거는  그냥  시설에서  주는  건가
# WER: 0.0  | CER: 0.0
#
# 183 ---------------
# REF: 네 어 케 오늘 주제를 가지고 어 얘기를 할 건데 일단 저희가
# HYP: 네 어 걔 오늘 주제를 가지고 어 얘기를 할 건데 일단 저희가
# 네  어  걔 (케)  오늘  주제를  가지고  어  얘기를  할  건데  일단  저희가
# WER: 0.083  | CER: 0.029411764705882353
#
# 184 ---------------
# REF: 반전이 있어
# HYP: 단전이 있어
# 단전이 (반전이)  있어
# WER: 0.5  | CER: 0.16666666666666666
#
# 185 ---------------
# REF: 아니 그런 생각이 들 수 있긴 한데 내가 궁금한건 그 사람들 그 아 진짜였을까 근데 어
# HYP: 아 근데 그런 생각이 들 수 있긴 한데 내가 궁금한 그 사람들이 진짜 그 아 진짜였을까 근데 어
# 아  근데 (아니)  그런  생각이  들  수  있긴  한데  내가  궁금한 (궁금한건)  그  사람들이  진짜 (사람들)  그  아  진짜였을까  근데  어
# WER: 0.312  | CER: 0.16666666666666666
#
# 186 ---------------
# REF: 뚜레쥬르 어
# HYP: 또래주를 어
# 또래주를 (뚜레쥬르)  어
# WER: 0.5  | CER: 0.6666666666666666
#
# 187 ---------------
# REF: 좋은 것도 있고 어떻게 뭐 뭐 재밌는 거를 즐기는 사람들은 이제 템플 스테이는 좀 추천하기가 좀 그렇고 그냥 머리를 식히고 싶다 뭐 아 좀 공기 좋은 거 마시고 싶다 이러면은 한번 가보는 것도 괜찮을 거 같애
# HYP: 좋은 것도 있고 어떻게 뭐 뭐 재밌는 거를 즐기는 사람들은 이제 템플스테이는 좀 추천하기는 좀 그렇고 그냥 머리를 식히고 싶다 뭐 아 좀 공기 좋은 거 마시고 싶다 이러면은 한번 가보는 것도 괜찮을 거 같애
# 좋은  것도  있고  어떻게  뭐  뭐  재밌는  거를  즐기는  사람들은  이제  템플  템플스테이는 (스테이는)  좀  추천하기는 (추천하기가)  좀  그렇고  그냥  머리를  식히고  싶다  뭐  아  좀  공기  좋은  거  마시고  싶다  이러면은  한번  가보는  것도  괜찮을  거  같애
# WER: 0.083  | CER: 0.017241379310344827
#
# 188 ---------------
# REF: 공기업이나 공무원 이런 거에 대해선 별로 생각이 없단 말이야
# HYP: 공기업이나 공무원 이런 거에 대해선 별로 생각이 없단 말이야
# 공기업이나  공무원  이런  거에  대해선  별로  생각이  없단  말이야
# WER: 0.0  | CER: 0.0
#
# 189 ---------------
# REF: 근데 오빠 같은 경우는 외국여행 갈 때 그 외국 음식 같은 거 먹거나 이러면 뭐 민감한 사람들은 물갈이 하거나 장염 걸려가지고 이렇게 고생하는 경우 있는데 그런 적은 없어
# HYP: 근데 오빠 같은 경우는 외국 여행 갈 때 그 외국 음식 같은 거 먹거나 이러면 뭐 게 민감한 사람들은 물갈이하거나 장염 걸려가지고 이렇게 고생하는 경우 있는데 그런 적은 없어
# 근데  오빠  같은  경우는  외국  여행 (외국여행)  갈  때  그  외국  음식  같은  거  먹거나  이러면  뭐  게  민감한  사람들은  물갈이  물갈이하거나 (하거나)  장염  걸려가지고  이렇게  고생하는  경우  있는데  그런  적은  없어
# WER: 0.179  | CER: 0.042105263157894736
#
# 190 ---------------
# REF: 진짜 얘 애들 솔 한번 풀어주는 날 마시고 진짜 조용히만 들어가면 상관이 없어
# HYP: 진짜 애들 술 한 번 풀어주는 날 마시고 진짜 조용히만 들어가면 상관이 없어
# 진짜  애들 (얘)  술 (애들)  한 (솔)  번 (한번)  풀어주는  날  마시고  진짜  조용히만  들어가면  상관이  없어
# WER: 0.308  | CER: 0.09302325581395349
#
# 191 ---------------
# REF: 어 그거 그냥 개 털었잖아 SKT가
# HYP: 어 그거 그냥 개털었잖아 에스케이티가
# 어  그거  그냥  개  개털었잖아 (털었잖아)  에스케이티가 (SKT가)
# WER: 0.5  | CER: 0.3157894736842105
#
# 192 ---------------
# REF: 게임에 대한 흥미도가 처음에 적용이 많이 되는 것 같애
# HYP: 게임에 대한 흥미도가 처음에 적용이 많이 되는 거 같애
# 게임에  대한  흥미도가  처음에  적용이  많이  되는  거 (것)  같애
# WER: 0.111  | CER: 0.03333333333333333
#
# 193 ---------------
# REF: 근데 십팔 라운드 나온다고 스프링에
# HYP: 근데 십 팔 년도 난다고 스프링 해
# 근데  십  팔  년도 (십팔)  난다고 (라운드)  스프링 (나온다고)  해 (스프링에)
# WER: 1.2  | CER: 0.42105263157894735
#
# 194 ---------------
# REF: 아 진짜
# HYP: 아 진짜
# 아  진짜
# WER: 0.0  | CER: 0.0
#
# 195 ---------------
# REF: 아 근데 좀 재미가 없긴해
# HYP: 아 근데 좀 재미가 없긴 해
# 아  근데  좀  재미가  없긴  해 (없긴해)
# WER: 0.4  | CER: 0.07142857142857142
#
# 196 ---------------
# REF: 좀 짠했는데 그래도
# HYP: 좀 짠했는데 그래두
# 좀  짠했는데  그래두 (그래도)
# WER: 0.333  | CER: 0.1
#
# 197 ---------------
# REF: 냉정하게
# HYP: 냉정하게
# 냉정하게
# WER: 0.0  | CER: 0.0
#
# 198 ---------------
# REF: 응 난 그거 예쁜 것 같애
# HYP: 음 난 그거 예쁜 거 같애
# 음 (응)  난  그거  예쁜  거 (것)  같애
# WER: 0.333  | CER: 0.14285714285714285
#
# 199 ---------------
# REF: 글쎄 아무래도 이제 주경야독이라고 낮에 일하고
# HYP: 글쎄 아무래도 이제 주경 야독이라고 낮에 일하고
# 글쎄  아무래도  이제  주경  야독이라고 (주경야독이라고)  낮에  일하고
# WER: 0.333  | CER: 0.04
#
# 200 ---------------
# REF: 근데 공무원은 진짜
# HYP: 근데 공무원은 진짜
# 근데  공무원은  진짜
# WER: 0.0  | CER: 0.0
#
# 201 ---------------
# REF: 그럼 뭐
# HYP: 그럼 뭐
# 그럼  뭐
# WER: 0.0  | CER: 0.0
#
# 202 ---------------
# REF: 내가 딱 들어갔을 때 학생회 형들이 진짜 엄청 착하고 다 좋으셨어 그래가지구 그 형들이 우리한테 엄청 잘해주고
# HYP: 내가 딱 들어갔을 때 학생회 형들이 진짜 엄청 착하고 다 좋으셨어 그래가지구 그 형들이 우리한테 엄청 잘해주고
# 내가  딱  들어갔을  때  학생회  형들이  진짜  엄청  착하고  다  좋으셨어  그래가지구  그  형들이  우리한테  엄청  잘해주고
# WER: 0.0  | CER: 0.0
#
# 203 ---------------
# REF: 너도 뜻대로 잘 안 돼서 그렇게 좀 있는건가 싶기도 내 생각에는 그런 거 같 싶기도 하고
# HYP: 너도 뜻대로지 안 돼서 그렇게 좀 있는 건가 싶기도 내 생각에는 그런가 싶기도 하고
# 너도  뜻대로  뜻대로지 (잘)  안  돼서  그렇게  좀  있는  건가 (있는건가)  싶기도  내  생각에는  그런  거  그런가 (같)  싶기도  하고
# WER: 0.438  | CER: 0.14285714285714285
#
# 204 ---------------
# REF: 그 하 칼하트
# HYP: 그 핫 카라트
# 그  핫 (하)  카라트 (칼하트)
# WER: 0.667  | CER: 0.42857142857142855
#
# 205 ---------------
# REF: 그렇기 때문에 진짜 죽을 힘을 다해서 어떻게든 내려와야 된대
# HYP: 그렇기 때문에 진짜 죽을 힘을 다해서 어떻게든 내려와야 된대
# 그렇기  때문에  진짜  죽을  힘을  다해서  어떻게든  내려와야  된대
# WER: 0.0  | CER: 0.0
#
# 206 ---------------
# REF: 그래서 그거 좀 음 좀 얘기 하고 있어 지는 아무튼 브랜드 할 생각은 없어
# HYP: 그래서 그거 좀 음 좀 얘기하고 있어 지는 아무도 브랜드 할 생각은 없어
# 그래서  그거  좀  음  좀  얘기  얘기하고 (하고)  있어  지는  아무도 (아무튼)  브랜드  할  생각은  없어
# WER: 0.214  | CER: 0.04878048780487805
#
# 207 ---------------
# REF: 그쪽 의료쪽으로는 안갈 거 같은데
# HYP: 그쪽 의료 쪽으로는 안 갈 거 같은데
# 그쪽  의료  쪽으로는  안 (의료쪽으로는)  갈 (안갈)  거  같은데
# WER: 0.8  | CER: 0.1111111111111111
#
# 208 ---------------
# REF: 근데 교수님들이 되게 많이 도와주신데
# HYP: 근데 교수님들이 되게 많이 도와주신대
# 근데  교수님들이  되게  많이  도와주신대 (도와주신데)
# WER: 0.2  | CER: 0.05
#
# 209 ---------------
# REF: 팔찌같은 것도 많이 구매를 해봤어요 혹시 그거에 대해서 그 혹시 구매를 해본 적 해본 적이나 기금을 이제 모금해본 적이 있으신지
# HYP: 팔찌 같은 것도 많이 구매를 해봤어요 혹시 그거에 대해서 그 혹시 구매를 해본 적 해본 적이나 기금을 이제 모금 해본 적 있으신지
# 팔찌  같은 (팔찌같은)  것도  많이  구매를  해봤어요  혹시  그거에  대해서  그  혹시  구매를  해본  적  해본  적이나  기금을  이제  모금  해본 (모금해본)  적 (적이)  있으신지
# WER: 0.25  | CER: 0.04225352112676056
#
# 210 ---------------
# REF: 그러고 할 거 하면 되지 않을까
# HYP: 그럼 할 거 하면 되지 않을까
# 그럼 (그러고)  할  거  하면  되지  않을까
# WER: 0.167  | CER: 0.11764705882352941
#
# 211 ---------------
# REF: 어떤 면에서
# HYP: 어떤 면에서
# 어떤  면에서
# WER: 0.0  | CER: 0.0
#
# 212 ---------------
# REF: 이번에 별로 못 갔지 잘
# HYP: 이번에 별로 못 갔지 잘
# 이번에  별로  못  갔지  잘
# WER: 0.0  | CER: 0.0
#
# 213 ---------------
# REF: 아 경찬 안잡혀 어어
# HYP: 아 경찰 안 잡혀 어
# 아  경찰  안 (경찬)  잡혀 (안잡혀)  어 (어어)
# WER: 1.0  | CER: 0.2727272727272727
#
# 214 ---------------
# REF: 그리고 뭐 그거 말고도 뭐 딱히 뭐 사야 될거는 없는 거 같은데
# HYP: 그리고 뭐 그거 말고도 뭐 딱히 뭐 사야 될 거는 없는 거 같은데
# 그리고  뭐  그거  말고도  뭐  딱히  뭐  사야  될  거는 (될거는)  없는  거  같은데
# WER: 0.167  | CER: 0.02857142857142857
#
# 215 ---------------
# REF: 밤에 나중에 알바 끝나고 나서 친구들이랑 고기를 먹고 헤어졌는데
# HYP: 밤에 나중에 알바 끝나고 나서 친구들이랑 고기를 먹고 헤어졌는데
# 밤에  나중에  알바  끝나고  나서  친구들이랑  고기를  먹고  헤어졌는데
# WER: 0.0  | CER: 0.0
#
# 216 ---------------
# REF: 이게 친구라는 게
# HYP: 이게 친구라는 게
# 이게  친구라는  게
# WER: 0.0  | CER: 0.0
#
# 217 ---------------
# REF: 이제 돈을 벌어야 되는데
# HYP: 이제 돈을 버려야 되는데
# 이제  돈을  버려야 (벌어야)  되는데
# WER: 0.25  | CER: 0.15384615384615385
#
# 218 ---------------
# REF: 어떻게 보면 이 세상이 조금 이제 잘 돼있긴 하지만 그 속속히 들어가서 깊숙이 보면 많이 부당한 것도 있고 그리고 우리 밑에 애들도 우리를 보면 부당하다고 느끼는 것도 있겠지 근데 나는
# HYP: 어떻게 보면 이 세상이 쪼끔 이제 잘 돼 있긴 하지만 그 숙소키 들어가서 깊숙히 보면 많이 부당한 것도 있고 그리고 우리 밑에 애들도 우리를 보면 부당하다고 느끼는 것도 있겠지 근데 나는
# 어떻게  보면  이  세상이  쪼끔 (조금)  이제  잘  돼  있긴 (돼있긴)  하지만  그  숙소키 (속속히)  들어가서  깊숙히 (깊숙이)  보면  많이  부당한  것도  있고  그리고  우리  밑에  애들도  우리를  보면  부당하다고  느끼는  것도  있겠지  근데  나는
# WER: 0.167  | CER: 0.06796116504854369
#
# 219 ---------------
# REF: 아 그 친구 어
# HYP: 아 그 친구 어
# 아  그  친구  어
# WER: 0.0  | CER: 0.0
#
# 220 ---------------
# REF: 근데 난 지나다니면은 그냥 응 그냥 어 그냥 그렇구나 아 아무 생각이 안 든단 말이야
# HYP: 근데 그냥 지나다니면은 그냥 음 그냥 어 그냥 그렇구나 아무 생각이 안 든단 말이야
# 근데  그냥 (난)  지나다니면은  그냥  음 (응)  그냥  어  그냥  그렇구나  아  아무  생각이  안  든단  말이야
# WER: 0.2  | CER: 0.10638297872340426
#
# 221 ---------------
# REF: 어 그래서
# HYP: 어 그래서
# 어  그래서
# WER: 0.0  | CER: 0.0
#
# 222 ---------------
# REF: 말이 그게 끝이야
# HYP: 말이 그게 끝이야
# 말이  그게  끝이야
# WER: 0.0  | CER: 0.0
#
# 223 ---------------
# REF: 아니야 근데 유럽 분위기를 느낄 수 있는
# HYP: 아니야 근데 유럽 분위기를 느낄 수 있는
# 아니야  근데  유럽  분위기를  느낄  수  있는
# WER: 0.0  | CER: 0.0
#
# 224 ---------------
# REF: 어 근 걔 그러니까 내가 어 몇 번 탔냐 했더니 자기도 세 번밖에 안 탔다는 거야
# HYP: 어 근데 걔 그러니까 내가 어 너 몇 번 탔냐 했더니 자기도 세 번밖에 안 탔다는 거야
# 어  근데 (근)  걔  그러니까  내가  어  너  몇  번  탔냐  했더니  자기도  세  번밖에  안  탔다는  거야
# WER: 0.125  | CER: 0.06666666666666667
#
# 225 ---------------
# REF: 둔산동이 가격이 되게 비싸잖아
# HYP: 그 눈에 가격이 되게 비싸잖아
# 그  눈에 (둔산동이)  가격이  되게  비싸잖아
# WER: 0.5  | CER: 0.25
#
# 226 ---------------
# REF: 그래서 이거는
# HYP: 그래서 이거는
# 그래서  이거는
# WER: 0.0  | CER: 0.0
#
# 227 ---------------
# REF: 응 그래서 제주도는 언제 가는 게 좋을까
# HYP: 응 그 제주도는 언제 가는 게 좋을까
# 응  그 (그래서)  제주도는  언제  가는  게  좋을까
# WER: 0.143  | CER: 0.09090909090909091
#
# 228 ---------------
# REF: 아 진짜
# HYP: 아 진짜
# 아  진짜
# WER: 0.0  | CER: 0.0
#
# 229 ---------------
# REF: 아무 생각이 없는데 알아 보는 알아 볼 필욘 없지
# HYP: 아무 생각이 없는데 알아보는 알아볼 필요는 없지
# 아무  생각이  없는데  알아  보는  알아보는 (알아)  알아볼 (볼)  필요는 (필욘)  없지
# WER: 0.556  | CER: 0.14814814814814814
#
# 230 ---------------
# REF: 이 이런 거
# HYP: 이 이런 거
# 이  이런  거
# WER: 0.0  | CER: 0.0
#
# 231 ---------------
# REF: 그렇지
# HYP: 그렇지
# 그렇지
# WER: 0.0  | CER: 0.0
#
# 232 ---------------
# REF: 내가 그런 걱정을 막 내비췄다면
# HYP: 내가 그런 걱정을 막 내비쳤다면
# 내가  그런  걱정을  막  내비쳤다면 (내비췄다면)
# WER: 0.2  | CER: 0.058823529411764705
#
# 233 ---------------
# REF: 아 그 나는 갈 때 기차가 좋아
# HYP: 아 그게 나는 갈 때 기차가 좋아
# 아  그게 (그)  나는  갈  때  기차가  좋아
# WER: 0.143  | CER: 0.058823529411764705
#
# 234 ---------------
# REF: 거기는
# HYP: 거기는
# 거기는
# WER: 0.0  | CER: 0.0
#
# 235 ---------------
# REF: 기숙사 기숙사 들어가기 전에 사야 될 게 많아서
# HYP: 기숙사 기숙사 들어가기 전에 사야 될 게 많아서
# 기숙사  기숙사  들어가기  전에  사야  될  게  많아서
# WER: 0.0  | CER: 0.0
#
# 236 ---------------
# REF: 어떻게 될 거 같애
# HYP: 어떻게 될 거 같애
# 어떻게  될  거  같애
# WER: 0.0  | CER: 0.0
#
# 237 ---------------
# REF: 내가 뭘 하는 건 아닌데
# HYP: 내가 뭘 하는 건 아닌데
# 내가  뭘  하는  건  아닌데
# WER: 0.0  | CER: 0.0
#
# 238 ---------------
# REF: 왜 굳이
# HYP: 왜 굳이
# 왜  굳이
# WER: 0.0  | CER: 0.0
#
# 239 ---------------
# REF: 또 애기가 중간에 한번 탈출을 해서
# HYP: 또 애기가 중간에 한 번 탈출을 해서
# 또  애기가  중간에  한  번 (한번)  탈출을  해서
# WER: 0.333  | CER: 0.05263157894736842
#
# 240 ---------------
# REF: 걔는 근데 SBS
# HYP: 걔는 네스비스
# 걔는  근데  네스비스 (SBS)
# WER: 0.667  | CER: 0.6666666666666666
#
# 241 ---------------
# REF: 응 너 어차피 너 리버풀 너 어 그 너 완전 그
# HYP: 근데 너 어차피 너 리버풀도 어 그 너 완전 그
# 근데 (응)  너  어차피  너  리버풀  리버풀도 (너)  어  그  너  완전  그
# WER: 0.273  | CER: 0.15384615384615385
#
# 242 ---------------
# REF: 준비를 되게 많이 하더라고
# HYP: 준비를 되게 많이 하더라고
# 준비를  되게  많이  하더라고
# WER: 0.0  | CER: 0.0
#
# 243 ---------------
# REF: 아 못하겠다 정말
# HYP: 아 못하겠다 정말
# 아  못하겠다  정말
# WER: 0.0  | CER: 0.0
#
# 244 ---------------
# REF: 잘했어
# HYP: 잘했어
# 잘했어
# WER: 0.0  | CER: 0.0
#
# 245 ---------------
# REF: 아 유연해 그게
# HYP: 아 유연해 그게
# 아  유연해  그게
# WER: 0.0  | CER: 0.0
#
# 246 ---------------
# REF: 저도 막 뉴스보고 그래봤는데
# HYP: 저도 막 뉴스 보고 막 그래봤는데
# 저도  막  뉴스  보고  막 (뉴스보고)  그래봤는데
# WER: 0.75  | CER: 0.2
#
# 247 ---------------
# REF: 하긴 거기 그거말고는 먹기 힘드니까
# HYP: 하긴 거기 그거 말고는 먹기 힘드니까
# 하긴  거기  그거  말고는 (그거말고는)  먹기  힘드니까
# WER: 0.4  | CER: 0.05263157894736842
#
# 248 ---------------
# REF: 그래서 꿈을 미리 잡아 놓는데 되게 중요한 것 같지 않아
# HYP: 그래서 꿈을 미리 잡아 놓는 게 되게 중요한 거 같지 않아
# 그래서  꿈을  미리  잡아  놓는  게 (놓는데)  되게  중요한  거 (것)  같지  않아
# WER: 0.3  | CER: 0.0967741935483871
#
# 249 ---------------
# REF: 하 정말 그래가지고 내가
# HYP: 아 정말 그래가지고 내가
# 아 (하)  정말  그래가지고  내가
# WER: 0.25  | CER: 0.07692307692307693
#
# 250 ---------------
# REF: 아 근데 난 약간 둘 다 이십 대처럼 보이니까
# HYP: 아 근데 난 약간 둘 다 이십 대처럼 보이니까
# 아  근데  난  약간  둘  다  이십  대처럼  보이니까
# WER: 0.0  | CER: 0.0
#
# 251 ---------------
# REF: 어 그렇게 분리가 되지
# HYP: 어 그렇게 분리가 되지
# 어  그렇게  분리가  되지
# WER: 0.0  | CER: 0.0
#
# 252 ---------------
# REF: 그런데 그 그 뭐 이제 의류같은 거 팔고 싶대
# HYP: 그런데 그 그 뭐 이제 의류 같은 거 팔고 싶대
# 그런데  그  그  뭐  이제  의류  같은 (의류같은)  거  팔고  싶대
# WER: 0.222  | CER: 0.04
#
# 253 ---------------
# REF: 한번 보긴 봐야 될 거 같은데 요 근처에 그런 데 있나
# HYP: 한 번 보긴 봐야 될 거 같은데 요 근처에 그런 데 있나
# 한  번 (한번)  보긴  봐야  될  거  같은데  요  근처에  그런  데  있나
# WER: 0.182  | CER: 0.03333333333333333
#
# 254 ---------------
# REF: 너한테
# HYP: 너한테
# 너한테
# WER: 0.0  | CER: 0.0
#
# 255 ---------------
# REF: 음 그러면 오십 이 사단에서 주로 맡으셨던 주특기는 어떤 주특기를 맡으셨나요 네
# HYP: 음 그믄 오십 이 산에서 주로 마트셨던 주택은 어떤 주택을 맞추셨나요
# 음  그믄 (그러면)  오십  이  산에서 (사단에서)  주로  마트셨던 (맡으셨던)  주택은 (주특기는)  어떤  주특기를  주택을 (맡으셨나요)  맞추셨나요 (네)
# WER: 0.583  | CER: 0.36363636363636365
#
# 256 ---------------
# REF: 어 근데 우리 오늘 일찍 가기로 했으니까 적당한 데 가자
# HYP: 어 근데 우리 오늘 일찍 가기로 했으니까 적당한 데 가자
# 어  근데  우리  오늘  일찍  가기로  했으니까  적당한  데  가자
# WER: 0.0  | CER: 0.0
#
# 257 ---------------
# REF: 그냥 뭐 무섭고 이런 게 아니라 진짜 사람 같지가 않아가지고 그냥 장난감 같은 느낌이 들거든
# HYP: 그냥 뭐 무섭고 이런 게 아니라 진짜 사람 같지가 않아가지구 그냥 장난감 같은 느낌이 들거든
# 그냥  뭐  무섭고  이런  게  아니라  진짜  사람  같지가  않아가지구 (않아가지고)  그냥  장난감  같은  느낌이  들거든
# WER: 0.067  | CER: 0.0196078431372549
#
# 258 ---------------
# REF: 그 너도 그 옛날에 거기 살았잖아
# HYP: 그 너도 그 옛날에 거기 살았잖아
# 그  너도  그  옛날에  거기  살았잖아
# WER: 0.0  | CER: 0.0
#
# 259 ---------------
# REF: 근데 내가 고기를 되게 좋아한단 말이야
# HYP: 근데 내가 고기를 되게 좋아한단 말이야
# 근데  내가  고기를  되게  좋아한단  말이야
# WER: 0.0  | CER: 0.0
#
# 260 ---------------
# REF: 그때 봤다고 내가 말했던 거 같은데 그래서 맨날
# HYP: 그때 받아먹 근데 말했던 거 같은데 그래서 맨날
# 그때  받아먹 (봤다고)  근데 (내가)  말했던  거  같은데  그래서  맨날
# WER: 0.25  | CER: 0.19230769230769232
#
# 261 ---------------
# REF: 아 예 감사합니다
# HYP: 감사합니다
# 아  예  감사합니다
# WER: 0.667  | CER: 0.4444444444444444
#
# 262 ---------------
# REF: 신기하다
# HYP: 신기하다
# 신기하다
# WER: 0.0  | CER: 0.0
#
# 263 ---------------
# REF: 하면 안 돼
# HYP: 하면 안 돼
# 하면  안  돼
# WER: 0.0  | CER: 0.0
#
# 264 ---------------
# REF: 참회를 하고
# HYP: 참여를 하고
# 참여를 (참회를)  하고
# WER: 0.5  | CER: 0.16666666666666666
#
# 265 ---------------
# REF: 그럼 너 이 학년은 어떻게 됐어 지금 일단은 다녀
# HYP: 그럼 너 이 학년은 어떻게 됐어 지금 일단은 다녀
# 그럼  너  이  학년은  어떻게  됐어  지금  일단은  다녀
# WER: 0.0  | CER: 0.0
#
# 266 ---------------
# REF: 그래서
# HYP: 그래서
# 그래서
# WER: 0.0  | CER: 0.0
#
# 267 ---------------
# REF: 좀 싫었어 나는 내가 노래를 못 한다고 생각해 가지고
# HYP: 좀 싫었어 난 내가 노랠 못 한다고 생각해가지고
# 좀  싫었어  난 (나는)  내가  노랠 (노래를)  못  한다고  생각해  생각해가지고 (가지고)
# WER: 0.444  | CER: 0.1724137931034483
#
# 268 ---------------
# REF: 한시쯤 될거다 모르겠다
# HYP: 한 시쯤 될 거다 모르겠다
# 한  시쯤  될 (한시쯤)  거다 (될거다)  모르겠다
# WER: 1.333  | CER: 0.16666666666666666
#
# 269 ---------------
# REF: 일단은 서울예대를 가고 싶은 이유가 아 난 과점퍼에 일단 반했어
# HYP: 일단은 서울예대를 가고 싶은 이유가 아 난 과잠팔 일단 반했어
# 일단은  서울예대를  가고  싶은  이유가  아  난  과잠팔 (과점퍼에)  일단  반했어
# WER: 0.1  | CER: 0.08571428571428572
#
# 270 ---------------
# REF: 반말을 할 수가 있어
# HYP: 반말을 할 수가 있어
# 반말을  할  수가  있어
# WER: 0.0  | CER: 0.0
#
# 271 ---------------
# REF: 그 쾌감이 더 큰 것 같애
# HYP: 그 쾌감이 더 큰 거 같애
# 그  쾌감이  더  큰  거 (것)  같애
# WER: 0.167  | CER: 0.07142857142857142
#
# 272 ---------------
# REF: 아니 군대도 안 갔다 왔는데 다까체를 어디서 배워
# HYP: 아니 군대도 안 갔다 왔는데 다 가채를 어디서 배워
# 아니  군대도  안  갔다  왔는데  다  가채를 (다까체를)  어디서  배워
# WER: 0.25  | CER: 0.1111111111111111
#
# 273 ---------------
# REF: 그리고 내가 봤을 때
# HYP: 그리고 내가 봤을 때
# 그리고  내가  봤을  때
# WER: 0.0  | CER: 0.0
#
# 274 ---------------
# REF: 통통이가 갑자기 우는 거야
# HYP: 뚱뚱이가 갑자기 우는 거야
# 뚱뚱이가 (통통이가)  갑자기  우는  거야
# WER: 0.25  | CER: 0.14285714285714285
#
# 275 ---------------
# REF: 근데 어차피 받을 건 다 똑같이 받지 않나
# HYP: 근데 어차피 받을 건 다 똑같이 받지 않나
# 근데  어차피  받을  건  다  똑같이  받지  않나
# WER: 0.0  | CER: 0.0
#
# 276 ---------------
# REF: 언제 짜냐 그거
# HYP: 언제 짜냐 그거
# 언제  짜냐  그거
# WER: 0.0  | CER: 0.0
#
# 277 ---------------
# REF: 아 진짜
# HYP: 아 진짜
# 아  진짜
# WER: 0.0  | CER: 0.0
#
# 278 ---------------
# REF: 분홍이는 진짜 확실히 그거 좋은데
# HYP: 분홍이는 진짜 확실히 그거 좋은데
# 분홍이는  진짜  확실히  그거  좋은데
# WER: 0.0  | CER: 0.0
#
# 279 ---------------
# REF: 이제 그 여자애랑 둘이
# HYP: 이제 그 여자애랑 둘이
# 이제  그  여자애랑  둘이
# WER: 0.0  | CER: 0.0
#
# 280 ---------------
# REF: 네 꾸준히 좀 아르바이트를 하게 됐습니다
# HYP: 네 꾸준히 좀 아르바이트를 파괴됐습니다
# 네  꾸준히  좀  아르바이트를  하게  파괴됐습니다 (됐습니다)
# WER: 0.333  | CER: 0.13636363636363635
#
# 281 ---------------
# REF: 새로운 경험을 했네
# HYP: 새로운 경험을 했네
# 새로운  경험을  했네
# WER: 0.0  | CER: 0.0
#
# 282 ---------------
# REF: 어떻게 보면 우리 입장에서는
# HYP: 어떻게 보면 우리 입장에선
# 어떻게  보면  우리  입장에선 (입장에서는)
# WER: 0.25  | CER: 0.13333333333333333
#
# 283 ---------------
# REF: 그 교수님 있는데 막
# HYP: 그 교수님 있는데 막
# 그  교수님  있는데  막
# WER: 0.0  | CER: 0.0
#
# 284 ---------------
# REF: 근데 그게 그런 것 같애
# HYP: 근데 그게 그런 거 같애
# 근데  그게  그런  거 (것)  같애
# WER: 0.2  | CER: 0.07692307692307693
#
# 285 ---------------
# REF: 아니 뭐 컵라면 같은 거 안 가져갔어
# HYP: 아니 뭐 컵라면 같은 거 안 가져갔어
# 아니  뭐  컵라면  같은  거  안  가져갔어
# WER: 0.0  | CER: 0.0
#
# 286 ---------------
# REF: 최대 빈 자리 있는 데로 들어가서 앉아야 될 거 아냐 그래서
# HYP: 최소 빈자리 있는 데로 들어가서 앉아야 될 거 아니야 그래서
# 최대  최소 (빈)  빈자리 (자리)  있는  데로  들어가서  앉아야  될  거  아니야 (아냐)  그래서
# WER: 0.364  | CER: 0.12121212121212122
#
# 287 ---------------
# REF: 약간 그런 느낌 들지
# HYP: 약간 그런 느낌 들지 않나
# 약간  그런  느낌  들지  않나
# WER: 0.25  | CER: 0.2727272727272727
#
# 288 ---------------
# REF: 가고 가고 싶어
# HYP: 가고 가고 싶어
# 가고  가고  싶어
# WER: 0.0  | CER: 0.0
#
# 289 ---------------
# REF: 내가 내가 지금까지 쓴 것 중에 제일 제일 좋은 거는
# HYP: 내가 내가 지금까지 쓴 것 중에 제일 제일 좋은 거는
# 내가  내가  지금까지  쓴  것  중에  제일  제일  좋은  거는
# WER: 0.0  | CER: 0.0
#
# 290 ---------------
# REF: 숙박비는 한 칠만 원 들고
# HYP: 숙박비 있는 사람 칠만 원 들고
# 숙박비  있는 (숙박비는)  사람 (한)  칠만  원  들고
# WER: 0.6  | CER: 0.2857142857142857
#
# 291 ---------------
# REF: 한자를
# HYP: 한자를
# 한자를
# WER: 0.0  | CER: 0.0
#
# 292 ---------------
# REF: 맞아 그렇긴한데 그냥 이걸 충분히 혼자서도 할 수 있는건데 나는 모이는 이유가 여럿이서만 할 수 있는 걸 할려고 모이는 건 줄 알았는데
# HYP: 맞아 그렇긴 한데 그냥 이걸 충분히 혼자서도 할 수 있는 건데 나는 모이는 이유가 여럿이서만 할 수 있는 걸 할려고 모이는 건 주 알았는데
# 맞아  그렇긴  한데 (그렇긴한데)  그냥  이걸  충분히  혼자서도  할  수  있는  건데 (있는건데)  나는  모이는  이유가  여럿이서만  할  수  있는  걸  할려고  모이는  건  주 (줄)  알았는데
# WER: 0.227  | CER: 0.04
#
# 293 ---------------
# REF: 카레도 같이 가고 막 그랬던 거 같애 기억엔 그랬던 거 같은데
# HYP: 카레도 같이 가고 막 그랬던 거 같애 기억엔 그랬던 거 같은데
# 카레도  같이  가고  막  그랬던  거  같애  기억엔  그랬던  거  같은데
# WER: 0.0  | CER: 0.0
#
# 294 ---------------
# REF: 좀 멋이 없어 경차니까
# HYP: 좀 멋이 없어 경차니까
# 좀  멋이  없어  경차니까
# WER: 0.0  | CER: 0.0
#
# 295 ---------------
# REF: 심포지엄 스물 다섯 명인 거 알아
# HYP: 심포지엄 스물 다섯 명인 거 알아
# 심포지엄  스물  다섯  명인  거  알아
# WER: 0.0  | CER: 0.0
#
# 296 ---------------
# REF: 이거 새로 산 건데
# HYP: 이거 새로 산 건데
# 이거  새로  산  건데
# WER: 0.0  | CER: 0.0
#
# 297 ---------------
# REF: 쌍둥이잖아 우리
# HYP: 짜 쌍둥이잖아 우리
# 짜  쌍둥이잖아  우리
# WER: 0.5  | CER: 0.25
#
# 298 ---------------
# REF: 별로 안 고통스러워
# HYP: 별로 안 고통스러워
# 별로  안  고통스러워
# WER: 0.0  | CER: 0.0
#
# 299 ---------------
# REF: 말 안 했어
# HYP: 말 안 했어
# 말  안  했어
# WER: 0.0  | CER: 0.0
#
# 300 ---------------
# REF: 어 중학교 때 십 년 전에
# HYP: 어 중학교 때 십 년 전에
# 어  중학교  때  십  년  전에
# WER: 0.0  | CER: 0.0
#
# 301 ---------------
# REF: 그럴 수
# HYP: 그럴
# 그럴  수
# WER: 0.5  | CER: 0.5
#
# 302 ---------------
# REF: 그 주변에 갔는데 그 지하철 역에 그런 게 많단 말이야
# HYP: 그 주변에 갔는데 그 지하철역에 그런 게 많단 말이야
# 그  주변에  갔는데  그  지하철  지하철역에 (역에)  그런  게  많단  말이야
# WER: 0.2  | CER: 0.03333333333333333
#
# 303 ---------------
# REF: 아 그런가 그럼 홍대 우리 계획짠 거 중에
# HYP: 아 그런가 그럼 홍대락 우리 계획 짠 거 중에
# 아  그런가  그럼  홍대락 (홍대)  우리  계획  짠 (계획짠)  거  중에
# WER: 0.375  | CER: 0.08695652173913043
#
# 304 ---------------
# REF: 먹고 너무 먹고 싶은 게 맥모닝
# HYP: 먹 너무 먹고 싶은 게 맨몸이
# 먹 (먹고)  너무  먹고  싶은  게  맨몸이 (맥모닝)
# WER: 0.333  | CER: 0.23529411764705882
#
# 305 ---------------
# REF: 진짜로
# HYP: 진짜로
# 진짜로
# WER: 0.0  | CER: 0.0
#
# 306 ---------------
# REF: 아니야
# HYP: 아니야
# 아니야
# WER: 0.0  | CER: 0.0
#
# 307 ---------------
# REF: 난 집에 가는 줄 알았다 근데 놀이기구 운영을 하라는 거야 그래서 무슨 소리지 나는 짐 처음 왔는데 무슨 놀이기구 운영인가 싶었는데
# HYP: 난 집에 가는 줄 알았다 근데 놀이기구 운영을 하라는 거야 그서 무슨 소리지 나는 짐 처음 왔는데 무슨 놀이기구 운영인가 싶었는데
# 난  집에  가는  줄  알았다  근데  놀이기구  운영을  하라는  거야  그서 (그래서)  무슨  소리지  나는  짐  처음  왔는데  무슨  놀이기구  운영인가  싶었는데
# WER: 0.048  | CER: 0.0136986301369863
#
# 308 ---------------
# REF: 어 서울은 더 비쌀 줄 알았어
# HYP: 어 서울은 더 비쌀 줄 알았어
# 어  서울은  더  비쌀  줄  알았어
# WER: 0.0  | CER: 0.0
#
# 309 ---------------
# REF: 아 안 해본
# HYP: 아 하는
# 아  안  하는 (해본)
# WER: 0.667  | CER: 0.6666666666666666
#
# 310 ---------------
# REF: 그리고 그때
# HYP: 그리고 그때
# 그리고  그때
# WER: 0.0  | CER: 0.0
#
# 311 ---------------
# REF: 새우덮밥 거기도 새우네
# HYP: 새우 덮밥 거기도 새우네
# 새우  덮밥 (새우덮밥)  거기도  새우네
# WER: 0.667  | CER: 0.08333333333333333
#
# 312 ---------------
# REF: 아 진짜 털도 돼 겨울이니까 되지 않을까
# HYP: 아 진짜 털도 돼 겨울이니까 되지 않을까
# 아  진짜  털도  돼  겨울이니까  되지  않을까
# WER: 0.0  | CER: 0.0
#
# 313 ---------------
# REF: 진짜 그래도 이 년제니까 기숙사에 계속 있어도 될 거 같기도 하고
# HYP: 진짜 그래도 이 년제니깐 기숙사에 계속 있어도 될 거 같기도 하고
# 진짜  그래도  이  년제니깐 (년제니까)  기숙사에  계속  있어도  될  거  같기도  하고
# WER: 0.091  | CER: 0.027777777777777776
#
# 314 ---------------
# REF: 만난다 보니까
# HYP: 만나다 보니까
# 만나다 (만난다)  보니까
# WER: 0.5  | CER: 0.14285714285714285
#
# 315 ---------------
# REF: 뭐 따른 놀이기구에서는 탔는데 왜 이 놀이기군 안 되냐 라고 말씀하시는 경우도 되게 많구 되게 진상이 되게 많아
# HYP: 뭐 따른 놀이기구에선 탔는데 왜 이 놀이기구는 안되냐 라고 말씀하시는 경우도 되게 많고 되게 진상이 되게 많아
# 뭐  따른  놀이기구에선 (놀이기구에서는)  탔는데  왜  이  놀이기군  놀이기구는 (안)  안되냐 (되냐)  라고  말씀하시는  경우도  되게  많고 (많구)  되게  진상이  되게  많아
# WER: 0.278  | CER: 0.0967741935483871
#
# 316 ---------------
# REF: 근데 나는 뭐 뭐 필요해서 딴다기보다는
# HYP: 근데 나는 뭐 뭐 필요해서 딴다기보다는
# 근데  나는  뭐  뭐  필요해서  딴다기보다는
# WER: 0.0  | CER: 0.0
#
# 317 ---------------
# REF: 거기도 그냥 가볼 생각 거기 나는 내가 알기로 아파트 생기고
# HYP: 거기도 그냥 가볼 생각이 거기 나는 내가 알기로 아파트 생기고
# 거기도  그냥  가볼  생각이 (생각)  거기  나는  내가  알기로  아파트  생기고
# WER: 0.1  | CER: 0.030303030303030304
#
# 318 ---------------
# REF: 근데 물고기를 보면은
# HYP: 근데 물고기를 보면은
# 근데  물고기를  보면은
# WER: 0.0  | CER: 0.0
#
# 319 ---------------
# REF: 뭐 오고가고 가 오고가고 하는 게 힘들고 너무 가까이 있으면은 기분이 안 나고
# HYP: 뭐 오고 가고 오고 가고 하는 게 힘들고 너무 가까이 있으면은 기분이 안 나고
# 뭐  오고  가고 (오고가고)  오고 (가)  가고 (오고가고)  하는  게  힘들고  너무  가까이  있으면은  기분이  안  나고
# WER: 0.308  | CER: 0.09302325581395349
#
# 320 ---------------
# REF: 책임지지
# HYP: 책임지지
# 책임지지
# WER: 0.0  | CER: 0.0
#
# 321 ---------------
# REF: 아빠 친구가 그거 한 사람 있었거든 서류전형 이거 뭐지
# HYP: 아빠 친구가 그거 한 사람 있었거든 서류 전형 이거 뭐지
# 아빠  친구가  그거  한  사람  있었거든  서류  전형 (서류전형)  이거  뭐지
# WER: 0.222  | CER: 0.03333333333333333
#
# 322 ---------------
# REF: 아아 그게 또 있네
# HYP: 아 그게 또 있네
# 아 (아아)  그게  또  있네
# WER: 0.25  | CER: 0.1
#
# 323 ---------------
# REF: 그 다음에 이거 벤치 하나도 안 하고 그거 하나도 여기 안 치고
# HYP: 그다음에 이거 벤치 하나도 안 하고 그 하나도 우기 안 치고
# 그  그다음에 (다음에)  이거  벤치  하나도  안  하고  그 (그거)  하나도  우기 (여기)  안  치고
# WER: 0.333  | CER: 0.08571428571428572
#
# 324 ---------------
# REF: 그냥 내가 생각 한 게 그냥 그걸 사고 싶어가지고 그냥 뭔가 비싼거
# HYP: 그냥 내가 생각한 게 그냥 그걸 사고 싶어가지고 그냥 뭔가 내 비싼 거
# 그냥  내가  생각  생각한 (한)  게  그냥  그걸  사고  싶어가지고  그냥  뭔가  내  비싼  거 (비싼거)
# WER: 0.417  | CER: 0.10810810810810811
#
# 325 ---------------
# REF: 근데 그 사람이 약간 그렇더라고
# HYP: 근데 그 사람이 약간 그렇더라고
# 근데  그  사람이  약간  그렇더라고
# WER: 0.0  | CER: 0.0
#
# 326 ---------------
# REF: 의학관으로 이동을 해야 돼 의학관에 한 십 일 층으로 이동을 해야 되니까 엘리베이터를 타야 되는데 그때 교수님이랑 또 마주친거야
# HYP: 의학관으로 이동을 해야 돼 의학과는 한 십 일 층으로 이동을 해야 되니까 엘레베이터를 타야 되는데 그때 교수님이랑 또 마주친 거야
# 의학관으로  이동을  해야  돼  의학과는 (의학관에)  한  십  일  층으로  이동을  해야  되니까  엘레베이터를 (엘리베이터를)  타야  되는데  그때  교수님이랑  또  마주친  거야 (마주친거야)
# WER: 0.211  | CER: 0.056338028169014086
#
# 327 ---------------
# REF: 근데 그 근데 그 쌤 생각보다 우리 학교에서 높은 쪽인가 봐
# HYP: 근데 그 근데 그 쌤 생각보다 우리 학교에서 높은 쪽인가 봐
# 근데  그  근데  그  쌤  생각보다  우리  학교에서  높은  쪽인가  봐
# WER: 0.0  | CER: 0.0
#
# 328 ---------------
# REF: 근데 코엑스 그거 말고 할 거 없잖아
# HYP: 근데 코엑스 그거 말고 할 거 없잖아
# 근데  코엑스  그거  말고  할  거  없잖아
# WER: 0.0  | CER: 0.0
#
# 329 ---------------
# REF: 어 근데 어 근데 다 없으셔가지고 이젠
# HYP: 어 근데 어 근데 다 없으셔가지고 이젠
# 어  근데  어  근데  다  없으셔가지고  이젠
# WER: 0.0  | CER: 0.0
#
# 330 ---------------
# REF: 어쨌든 나는 이제 가정을 같이 이끌어 나갈려면
# HYP: 어쨌든 나는 이제 가정을 같이 끌어나갈려면
# 어쨌든  나는  이제  가정을  같이  이끌어  끌어나갈려면 (나갈려면)
# WER: 0.286  | CER: 0.08
#
# 331 ---------------
# REF: 그 옛날처럼 옛날에 정 문화가 다시 다시 돌아갈 수 있을 거 같은데 요즘은 너무 개인주의 문화가 너무 이렇게 심하게 가고 있어가지구 나 같은 경우에도
# HYP: 그 옛날처럼 옛날에 정문화가 다시 다시 돌아갈 수 있을 거 같은데 요즘은 너무 개인주의 문화가 너무 이케 심하게 가고 있어가지구 나 같은 경우에도
# 그  옛날처럼  옛날에  정  정문화가 (문화가)  다시  다시  돌아갈  수  있을  거  같은데  요즘은  너무  개인주의  문화가  너무  이케 (이렇게)  심하게  가고  있어가지구  나  같은  경우에도
# WER: 0.125  | CER: 0.03614457831325301
#
# 332 ---------------
# REF: 따른 거는 아무 것도 모른대 그래서
# HYP: 따른 거는 아무것도 모른대 그래서
# 따른  거는  아무  아무것도 (것도)  모른대  그래서
# WER: 0.333  | CER: 0.05263157894736842
#
# 333 ---------------
# REF: 너 신과 함께 제대로 봤어
# HYP: 너 신과 함께 제대로 봤어
# 너  신과  함께  제대로  봤어
# WER: 0.0  | CER: 0.0
#
# 334 ---------------
# REF: 나 어제
# HYP: 나 어제
# 나  어제
# WER: 0.0  | CER: 0.0
#
# 335 ---------------
# REF: 딴 얘기하자
# HYP: 딴 얘기 하자
# 딴  얘기  하자 (얘기하자)
# WER: 1.0  | CER: 0.16666666666666666
#
# 336 ---------------
# REF: 그리고 아 내가 진짜 좀
# HYP: 그리고 아 내가 진짜 쫌
# 그리고  아  내가  진짜  쫌 (좀)
# WER: 0.2  | CER: 0.07692307692307693
#
# 337 ---------------
# REF: 나 이제 삼 월부터 학 학원 다닌단 말이야
# HYP: 나 이제 삼 월부터 학원 다닌단 말이야
# 나  이제  삼  월부터  학  학원  다닌단  말이야
# WER: 0.125  | CER: 0.08695652173913043
#
# 338 ---------------
# REF: 어 아 그래서 그런 거야
# HYP: 어 아 그래서 그런 거야
# 어  아  그래서  그런  거야
# WER: 0.0  | CER: 0.0
#
# 339 ---------------
# REF: 다른 게임을 했잖아
# HYP: 따른 게임을 했잖아
# 따른 (다른)  게임을  했잖아
# WER: 0.333  | CER: 0.1
#
# 340 ---------------
# REF: 근까 내말은 맨유도 이제 안 좋다는 거지
# HYP: 그니까 내 말은 맨유도 이제 안 좋다는 거지
# 그니까  내 (근까)  말은 (내말은)  맨유도  이제  안  좋다는  거지
# WER: 0.429  | CER: 0.13636363636363635
#
# 341 ---------------
# REF: 되게 너 유명해져있는 거 아니야
# HYP: 되게 너 유명해져 있는 거 아니야
# 되게  너  유명해져  있는 (유명해져있는)  거  아니야
# WER: 0.4  | CER: 0.058823529411764705
#
# 342 ---------------
# REF: 어 그런 거 같긴 하네
# HYP: 어 그런 거 같긴 하네
# 어  그런  거  같긴  하네
# WER: 0.0  | CER: 0.0
#
# 343 ---------------
# REF: 왜 유료야
# HYP: 왜 유료야
# 왜  유료야
# WER: 0.0  | CER: 0.0
#
# 344 ---------------
# REF: 그래서 그 부담감이랑 젖었을 때 얼거랑 찝찝한걸 생각하면은 그냥은 절대 못가겠는 거야
# HYP: 그래서 그 부담감이랑 젖었을 때 얼 거랑 찝찝한 걸 생각하면은 그냥은 절대 못 가겠는 거야
# 그래서  그  부담감이랑  젖었을  때  얼  거랑  찝찝한 (얼거랑)  걸 (찝찝한걸)  생각하면은  그냥은  절대  못  가겠는 (못가겠는)  거야
# WER: 0.5  | CER: 0.06382978723404255
#
# 345 ---------------
# REF: 아 진짜 안 미술관 되게 싫어하는데
# HYP: 아 진짜 난 미술관 되게 싫어하는데
# 아  진짜  난 (안)  미술관  되게  싫어하는데
# WER: 0.167  | CER: 0.05263157894736842
#
# 346 ---------------
# REF: 응 돈 주고 들어가면 되잖아
# HYP: 응 돈 주고 들어가면 되지
# 응  돈  주고  들어가면  되지 (되잖아)
# WER: 0.2  | CER: 0.13333333333333333
#
# 347 ---------------
# REF: 거기를 갔다와서 다시 일을 어떻게 시작해야되는지 조금 체계적으로 생각을 했는데 오빠는 휴가를 갈 때 뭐 어디 쪽으로 가고 싶어
# HYP: 거기를 갔다 와서 다시 일을 어떻게 시작해야 되는지 쪼끔 체계적으로 생각을 하는데 오빠는 휴가를 갈 때 뭐 어디 쪽으로 가고 싶어
# 거기를  갔다  와서 (갔다와서)  다시  일을  어떻게  시작해야  되는지 (시작해야되는지)  쪼끔 (조금)  체계적으로  생각을  하는데 (했는데)  오빠는  휴가를  갈  때  뭐  어디  쪽으로  가고  싶어
# WER: 0.316  | CER: 0.07142857142857142
#
# 348 ---------------
# REF: 코엑스에서 밥 먹는 것도 괜찮은 것 같은데 애들이 홍대 가서 먹자 해서
# HYP: 코엑스에서 밥 먹는 것도 괜찮은 거 같은데 애들이 홍대 가서 먹자 해서
# 코엑스에서  밥  먹는  것도  괜찮은  거 (것)  같은데  애들이  홍대  가서  먹자  해서
# WER: 0.083  | CER: 0.02564102564102564
#
# 349 ---------------
# REF: 다른 사람한테 그걸 설득시킬려면 엄청 무한하게 노력을 해야 되기 때문에 항상 긴장하며 사는데 오빠도 그렇게 많이 긴장하며 살지
# HYP: 다른 사람한테 그걸 설득시킬려면 엄청 무안하게 노력을 해야 되기 때문에 항상 긴장하면 사는데 오빠도 그렇게 많이 긴장하면 살지
# 다른  사람한테  그걸  설득시킬려면  엄청  무안하게 (무한하게)  노력을  해야  되기  때문에  항상  긴장하면 (긴장하며)  사는데  오빠도  그렇게  많이  긴장하면 (긴장하며)  살지
# WER: 0.167  | CER: 0.04285714285714286
#
# 350 ---------------
# REF: 응 나도 그렇게 생각을 하고 예상을 하고 갔었는데 막상 가서 보니까는
# HYP: 응 나도 그렇게 생각을 하고 예상을 하고 갔었는데 막상 가서 보니까는
# 응  나도  그렇게  생각을  하고  예상을  하고  갔었는데  막상  가서  보니까는
# WER: 0.0  | CER: 0.0
#
# 351 ---------------
# REF: 음 알겠어
# HYP: 응 알겠어
# 응 (음)  알겠어
# WER: 0.5  | CER: 0.2
#
# 352 ---------------
# REF: 아 그래 나한테 뭐 다른 거 물어보지 않았어 아닌가
# HYP: 아 그래 나한테 따른 거 물어보지 않았어 아닌가
# 아  그래  나한테  뭐  따른 (다른)  거  물어보지  않았어  아닌가
# WER: 0.222  | CER: 0.10714285714285714
#
# 353 ---------------
# REF: 응 개 떨었는데
# HYP: 응 개 떨었는데
# 응  개  떨었는데
# WER: 0.0  | CER: 0.0
#
# 354 ---------------
# REF: 그 뭔가 양쪽발이 묶여있어서 되게 불편할 거 같애
# HYP: 그 뭔가 양쪽 발이 묶여있어서 되게 불편할 거 같애
# 그  뭔가  양쪽  발이 (양쪽발이)  묶여있어서  되게  불편할  거  같애
# WER: 0.25  | CER: 0.037037037037037035
#
# 355 ---------------
# REF: 화학과야
# HYP: 화학과야
# 화학과야
# WER: 0.0  | CER: 0.0
#
# 356 ---------------
# REF: 아니 바꾸지마 아 근데 너 이 옷 옷 어디서 샀냐
# HYP: 아니 바꾸지 마 아 근데 너 이거 옷 옷 어디서 샀냐
# 아니  바꾸지  마 (바꾸지마)  아  근데  너  이거 (이)  옷  옷  어디서  샀냐
# WER: 0.3  | CER: 0.07407407407407407
#
# 357 ---------------
# REF: 그리고 진짜 막 명작을 남긴 사람들은 그거에 대해 미쳐가지구 오히려 좀 강박증세까지 보일 정도로 어 그런 게 있는데 그런 거에 대해 쪼끔 공감합니다 성실함
# HYP: 그리고 진짜 막 명작을 남긴 사람들은 그거에 대해 미처가지고 오히려 좀 막 강박증 색깔까지 보일 정도로 어 그런 게 있는데 그런 거에 대해 쪼끔 공감합니다 성실함
# 그리고  진짜  막  명작을  남긴  사람들은  그거에  대해  미처가지고 (미쳐가지구)  오히려  좀  막  강박증  색깔까지 (강박증세까지)  보일  정도로  어  그런  게  있는데  그런  거에  대해  쪼끔  공감합니다  성실함
# WER: 0.167  | CER: 0.08139534883720931
#
# 358 ---------------
# REF: 어쨌든 에
# HYP: 어쨌든 에
# 어쨌든  에
# WER: 0.0  | CER: 0.0
#
# 359 ---------------
# REF: 또 인지 능력이 쪼금 떨어지시다 보니까 했던 말 계속 똑같이 해 드려야 돼 이렇게 하시면 안 됩니다 이런 거를 계속 하셔야 돼 그리고 또
# HYP: 인지 능력이 쪼끔 떨어지시다 보니까 했던 말 계속 똑같이 해드려야 돼 이렇게 하시면 안 됩니다 이런 거를 계속하셔야 돼 그리고 또
# 또  인지  능력이  쪼끔 (쪼금)  떨어지시다  보니까  했던  말  계속  똑같이  해  해드려야 (드려야)  돼  이렇게  하시면  안  됩니다  이런  거를  계속  계속하셔야 (하셔야)  돼  그리고  또
# WER: 0.25  | CER: 0.06578947368421052
#
# 360 ---------------
# REF: 뭐 예를 들어서 코인노래방
# HYP: 뭐 예를 들어서 코인 노래방
# 뭐  예를  들어서  코인  노래방 (코인노래방)
# WER: 0.5  | CER: 0.07142857142857142
#
# 361 ---------------
# REF: 그 근데 가는 데 시간이 너무 오래 걸려 그 코엑스랑 뭐 디디피 했었잖아
# HYP: 아 그 근데 가는데 시간이 너무 오래 걸려 그 코엑스랑 뭐 이 디지페 했었잖아
# 아  그  근데  가는  가는데 (데)  시간이  너무  오래  걸려  그  코엑스랑  뭐  이  디지페 (디디피)  했었잖아
# WER: 0.385  | CER: 0.175
#
# 362 ---------------
# REF: 구하자고
# HYP: 구하자고
# 구하자고
# WER: 0.0  | CER: 0.0
#
# 363 ---------------
# REF: 그래서 우리가 말 바꿔가지고
# HYP: 그래서 우리가 말 바꿔가지고
# 그래서  우리가  말  바꿔가지고
# WER: 0.0  | CER: 0.0
#
# 364 ---------------
# REF: 근데 그렇다고해서 한화 한화 정글 아무것도 못 했잖아
# HYP: 근데 그렇다고 해서 하나 하나 전골 아무것도 못 했잖
# 근데  그렇다고  해서 (그렇다고해서)  하나 (한화)  하나 (한화)  전골 (정글)  아무것도  못  했잖 (했잖아)
# WER: 0.75  | CER: 0.27586206896551724
#
# 365 ---------------
# REF: 안 먹을래
# HYP: 안 먹을래
# 안  먹을래
# WER: 0.0  | CER: 0.0
#
# 366 ---------------
# REF: 곤지암에 사이렌으로 유명한 여자애 뭐
# HYP: 곤지암에 사이렌으로 유명한 여자애
# 곤지암에  사이렌으로  유명한  여자애  뭐
# WER: 0.2  | CER: 0.1
#
# 367 ---------------
# REF: 아 빨리 달라고 사람들한테 구걸해봐
# HYP: 아 빨리 달라고 사람들한테 그걸 해봐
# 아  빨리  달라고  사람들한테  그걸  해봐 (구걸해봐)
# WER: 0.4  | CER: 0.10526315789473684
#
# 368 ---------------
# REF: 미쳤냐
# HYP: 좋냐
# 좋냐 (미쳤냐)
# WER: 1.0  | CER: 0.6666666666666666
#
# 369 ---------------
# REF: 그 분이 알바 경력 있냐고 물어 봤을 때 난 좀 쫄렸어 한마음
# HYP: 그분이 알바 경력 있냐고 물어봤을 때 난 쫌 쫄렸어 한마음
# 그  그분이 (분이)  알바  경력  있냐고  물어  물어봤을 (봤을)  때  난  쫌 (좀)  쫄렸어  한마음
# WER: 0.417  | CER: 0.08823529411764706
#
# 370 ---------------
# REF: 그러면 이 월 십칠 일이면은
# HYP: 그럼 이 월 십 칠 일이면은
# 그럼 (그러면)  이  월  십  칠 (십칠)  일이면은
# WER: 0.6  | CER: 0.2
#
# 371 ---------------
# REF: 그 글쎄요 이제 어떻게 보면 이제 과거의 아픈 기억을 이제 좀
# HYP: 글 글쎄 이제 어떻게 보면 이제 과거에 아픈 기억을 이제 좀
# 글 (그)  글쎄 (글쎄요)  이제  어떻게  보면  이제  과거에 (과거의)  아픈  기억을  이제  좀
# WER: 0.273  | CER: 0.08823529411764706
#
# 372 ---------------
# REF: 어 그때 시험 봐도 되는 거야 그러면
# HYP: 어 그때 시험 봐도 되는 거야 그러면
# 어  그때  시험  봐도  되는  거야  그러면
# WER: 0.0  | CER: 0.0
#
# 373 ---------------
# REF: 그 차개비 부인
# HYP: 그 차게비 부인
# 그  차게비 (차개비)  부인
# WER: 0.333  | CER: 0.125
#
# 374 ---------------
# REF: 응 빅스비 끄면은 눌렀을 때 아무일도 안 일어난대 아니 이거를 왜 만들어놨는지 이해가 안 되긴 하는데
# HYP: 응 빅스비 끄면은 눌렀을 때 아무 일도 안 일어난대 아니 이거를 왜 만들어 놨는지 이해가 안 되긴 하는데
# 응  빅스비  끄면은  눌렀을  때  아무  일도 (아무일도)  안  일어난대  아니  이거를  왜  만들어  놨는지 (만들어놨는지)  이해가  안  되긴  하는데
# WER: 0.25  | CER: 0.03571428571428571
#
# 375 ---------------
# REF: 물론 재미가 없다는 건 아니거든 근데 처음보는 사람한테 할 얘기는 아니다 이거지
# HYP: 물론 재미가 없단 건 아니거든 근데 처음 보는 사람한테 할 얘기는 아니다 이거지
# 물론  재미가  없단 (없다는)  건  아니거든  근데  처음  보는 (처음보는)  사람한테  할  얘기는  아니다  이거지
# WER: 0.25  | CER: 0.06818181818181818
#
# 376 ---------------
# REF: 언제 한 번 만들어볼 수 있을까라는 생각 때문에
# HYP: 언제 한 번 만들 수 있을까란 생각 때문에
# 언제  한  번  만들 (만들어볼)  수  있을까란 (있을까라는)  생각  때문에
# WER: 0.25  | CER: 0.15384615384615385
#
# 377 ---------------
# REF: 어떤 식으로
# HYP: 어떤 식으로
# 어떤  식으로
# WER: 0.0  | CER: 0.0
#
# 378 ---------------
# REF: 그 하나하나 그
# HYP: 그 하나하나 그
# 그  하나하나  그
# WER: 0.0  | CER: 0.0
#
# 379 ---------------
# REF: 당연한 거 아니야
# HYP: 당연한 거 아니야
# 당연한  거  아니야
# WER: 0.0  | CER: 0.0
#
# 380 ---------------
# REF: 응 괜찮을 거 같애
# HYP: 응 괜찮을 거 같애
# 응  괜찮을  거  같애
# WER: 0.0  | CER: 0.0
#
# 381 ---------------
# REF: 어 난 난 근데 딱 봤을 때 그냥 약간 그래보이는 사람들이 있잖아
# HYP: 어 난 난 근데 딱 봤을 때 그냥 약간 그래 보이는 사람들이 있잖아
# 어  난  난  근데  딱  봤을  때  그냥  약간  그래  보이는 (그래보이는)  사람들이  있잖아
# WER: 0.167  | CER: 0.027777777777777776
#
# 382 ---------------
# REF: 거긴 차가 없잖아
# HYP: 거긴 차가 없잖아
# 거긴  차가  없잖아
# WER: 0.0  | CER: 0.0
#
# 383 ---------------
# REF: 아침에 한강을
# HYP: 아침에 한강을
# 아침에  한강을
# WER: 0.0  | CER: 0.0
#
# 384 ---------------
# REF: 십 오만 원 해가지고 이백만 원 일 주일하면 이백만 원 드는 거 같더라고요
# HYP: 십 오만 원 해가지고 이백만 원 일주일 하면 이백만 원 드는 거 같더라고
# 십  오만  원  해가지고  이백만  원  일주일 (일)  하면 (주일하면)  이백만  원  드는  거  같더라고 (같더라고요)
# WER: 0.231  | CER: 0.07317073170731707
#
# 385 ---------------
# REF: 뭐 너 이십 대 초반대부터 그럼 일한 거야
# HYP: 뭐 뭐 이십 대 초반 때부터 그럼 일한 거야
# 뭐  뭐 (너)  이십  대  초반  때부터 (초반대부터)  그럼  일한  거야
# WER: 0.375  | CER: 0.13043478260869565
#
# 386 ---------------
# REF: 종이비행기는 아니고 애들이 이제
# HYP: 정희 비행기는 아니고 애들이 이제
# 정희  비행기는 (종이비행기는)  아니고  애들이  이제
# WER: 0.5  | CER: 0.17647058823529413
#
# 387 ---------------
# REF: 그럼 우리 그 얘기 하자
# HYP: 그럼 우리 그 얘기 하자
# 그럼  우리  그  얘기  하자
# WER: 0.0  | CER: 0.0
#
# 388 ---------------
# REF: 그래서
# HYP: 그래서
# 그래서
# WER: 0.0  | CER: 0.0
#
# 389 ---------------
# REF: 그러면은 일단 오늘 한번 가서 뭐 사야 되는지 뭐 좋은 거 있는지 한번 보자
# HYP: 그러면은 일단 오늘 한 번 가서 뭐 사야 되는지 뭐 좋은 거 있는지 한 번 보자
# 그러면은  일단  오늘  한  번 (한번)  가서  뭐  사야  되는지  뭐  좋은  거  있는지  한  번 (한번)  보자
# WER: 0.286  | CER: 0.047619047619047616
#
# 390 ---------------
# REF: 네 알겠습니다 그냥 그러고 끊는다니까
# HYP: 네 알겠습니다 그냥 그러고 끊는다니까
# 네  알겠습니다  그냥  그러고  끊는다니까
# WER: 0.0  | CER: 0.0
#
# 391 ---------------
# REF: 아니 괜찮아 근데
# HYP: 아이 괜찮아 근데
# 아이 (아니)  괜찮아  근데
# WER: 0.333  | CER: 0.1111111111111111
#
# 392 ---------------
# REF: 근데 걔가 이번에 사 월 작년 사 월인가 그때 쯤에 그만두면서 좀 안 좋은 말 같은 거 하고 다니고 그랬대
# HYP: 근데 걔가 이번에 사 월 작년 사 월인가 그때쯤에 그만두면서 좀 안 좋은 말 같은 거 하고 다니고 그랬대
# 근데  걔가  이번에  사  월  작년  사  월인가  그때  그때쯤에 (쯤에)  그만두면서  좀  안  좋은  말  같은  거  하고  다니고  그랬대
# WER: 0.1  | CER: 0.01694915254237288
#
# 393 ---------------
# REF: 나는 날이가면 갈수록
# HYP: 나는 날이 가면 갈수록
# 나는  날이  가면 (날이가면)  갈수록
# WER: 0.667  | CER: 0.09090909090909091
#
# 394 ---------------
# REF: 어 뭐 전도 유망하기는 하지
# HYP: 아 뭐 전도 유망하긴 하지
# 아 (어)  뭐  전도  유망하긴 (유망하기는)  하지
# WER: 0.4  | CER: 0.2
#
# 395 ---------------
# REF: 날짜를
# HYP: 날짜를
# 날짜를
# WER: 0.0  | CER: 0.0
#
# 396 ---------------
# REF: 뭐 마이클조던 뭐 호날두 메시 뭐 이런
# HYP: 뭐 마이크 조던 뭐 호날두 메시 뭐 이런
# 뭐  마이크  조던 (마이클조던)  뭐  호날두  메시  뭐  이런
# WER: 0.286  | CER: 0.09523809523809523
#
# 397 ---------------
# REF: 그거 하면 뭐 이제 우승팀이 대충 나오지 않을까 이피엘
# HYP: 그거 하면 뭐 이제 우승 팀이 대충 나오지 않을까 이벤
# 그거  하면  뭐  이제  우승  팀이 (우승팀이)  대충  나오지  않을까  이벤 (이피엘)
# WER: 0.333  | CER: 0.1
#
# 398 ---------------
# REF: 왜냐면은 최대한 빨리 그만두는 게 낫지 않나 어차피 한 지 얼마 안 됐으니까 그래서 연락을 드렸는데
# HYP: 왜냐면은 최대한 빨리 그만두는 게 낫지 않나 어차피 한지 얼마 안 됐으니까 그래서 연락을 드렸는데
# 왜냐면은  최대한  빨리  그만두는  게  낫지  않나  어차피  한  한지 (지)  얼마  안  됐으니까  그래서  연락을  드렸는데
# WER: 0.125  | CER: 0.01818181818181818
#
# 399 ---------------
# REF: 똑같이 살아왔는데
# HYP: 똑같이 살아왔는데
# 똑같이  살아왔는데
# WER: 0.0  | CER: 0.0
#
# N DELETE    : 2403
# N SUBSTITUTE: 358
# N INSERT    : 113
# WER: 0.15849400000000005
